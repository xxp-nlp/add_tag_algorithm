# %% [markdown]
# <a href="https://colab.research.google.com/github/xxp-nlp/add_tag_algorithm/blob/main/2021_8_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# 正确文的分词处理，转化成chunk的格式 .phrase .trim_phrase  .dst   .tag
filename = '/content/CiWoTestdata-Correct.txt'

dependancy = re.compile(r'''(?:\*\s\d+\s) # キャプチャ対象外
             (-?\d+)      # 数字(係り先)
                      ''', re.VERBOSE)

class Morph:
    def __init__(self, line):
        cols = line.split(' ')
        self.surface = cols[0] # 表層形(surface) 

class Chunk_correct:
    def __init__(self, morphs, dst, id):
        self.morphs = morphs
        self.dst  = dst  # 係り先文節インデックス番号
        self.id = id
        self.phrase = ''.join([morph.surface for morph in morphs]) # 文節
        self.trim_phrase = self.phrase.replace('、','')
        self.tag = 'KEEP'

sentences = []
chunks = []
morphs = []
ids = []
dic_correct = {}
i = 0
with open(filename, mode='r') as f:
  for line in f:  # 1行ずつ読込
    dependancies = dependancy.match(line)
    fields = line.split(' ')


    if fields[0] == '#':
      id = fields[1]
      continue

    # EOSまたは係り受け解析結果でない場合
    if not (line == 'EOS\n' or dependancies):
      morphs.append(Morph(line))


    # EOSまたは係り受け解析結果で、形態素解析結果がある場合
    elif len(morphs) > 0:
      chunks.append(Chunk_correct(morphs, dst, id))
      morphs = []  

    # 係り受け結果の場合
    if dependancies:
      dst = int(dependancies.group(1))

    # EOSで係り受け結果がある場合
    if line == 'EOS\n' and len(chunks) > 0:
      sentences.append(chunks)
      chunks = []
      dic_correct[i] = [sentences,id]
      i+=1

for i, chunk in enumerate(sentences[9]):
    print('{}: {}  係り先:{} {}'.format(i, chunk.trim_phrase, chunk.dst, chunk.phrase))
    print(type(chunk.phrase),type(chunk.trim_phrase))
# Out:
# 0: 同大統領の  係り先:1 同大統領の
# <class 'str'> <class 'str'>
# 1: 首都脱出は  係り先:9 首都脱出は
# <class 'str'> <class 'str'>
# 2: 先に  係り先:9 先に
# <class 'str'> <class 'str'>
# 3: インタファクス通信が  係り先:9 インタファクス通信が
# <class 'str'> <class 'str'>
# 4: 六日  係り先:9 六日、
# <class 'str'> <class 'str'>
# 5: グロズヌイの  係り先:6 グロズヌイの
# <class 'str'> <class 'str'>
# 6: 軍事筋の  係り先:7 軍事筋の
# <class 'str'> <class 'str'>
# 7: 情報と  係り先:8 情報と
# <class 'str'> <class 'str'>
# 8: して  係り先:9 して
# <class 'str'> <class 'str'>
# 9: 伝えたが  係り先:13 伝えたが、
# <class 'str'> <class 'str'>
# 10: ロシア政府が  係り先:12 ロシア政府が
# <class 'str'> <class 'str'>
# 11: 公式に  係り先:12 公式に
# <class 'str'> <class 'str'>
# 12: 認めたのは  係り先:13 認めたのは
# <class 'str'> <class 'str'>
# 13: 初めて。  係り先:-1 初めて。
# <class 'str'> <class 'str'>

# %%
# 错误文的分词处理，转化成chunk的格式 .phrase .trim_phrase  .dst   .tag

filename = '/content/CiWoTestdata.txt'

dependancy = re.compile(r'''(?:\*\s\d+\s) # キャプチャ対象外
             (-?\d+)      # 数字(係り先)
                      ''', re.VERBOSE)

class Morph:
    def __init__(self, line):
        cols = line.split(' ')
        self.surface = cols[0] # 表層形(surface)


class Chunk_wrong:
    def __init__(self, morphs, dst, id):
        self.morphs = morphs
        self.dst  = dst  # 係り先文節インデックス番号
        self.id = id
        self.phrase = ''.join([morph.surface for morph in morphs]) # 文節
        self.trim_phrase = self.phrase.replace('、','')
        self.tag = 'KEEP'

dic_wrong = {}
sentences_wrong = []
chunks = []
morphs = []
ids = []
i = 0
with open(filename, mode='r') as f:
  for line in f:  # 1行ずつ読込
    dependancies = dependancy.match(line)
    fields = line.split(' ')


    if fields[0] == '#':
      id = fields[1]
      continue

    # EOSまたは係り受け解析結果でない場合
    if not (line == 'EOS\n' or dependancies):
      morphs.append(Morph(line))


    # EOSまたは係り受け解析結果で、形態素解析結果がある場合
    elif len(morphs) > 0:
      chunks.append(Chunk_wrong(morphs, dst, id))
      morphs = []  

    # 係り受け結果の場合
    if dependancies:
      dst = int(dependancies.group(1))

    # EOSで係り受け結果がある場合
    if line == 'EOS\n' and len(chunks) > 0:
      sentences_wrong.append(chunks)
      chunks = []
      dic_wrong[i] = [sentences_wrong,id]
      i+=1


# for i, chunk in enumerate(sentences_wrong[2]):
#     print('{}: {}  係り先:{} {}'.format(i, chunk.trim_phrase, chunk.dst, chunk.tag))

# %%
# scale the data  对齐数据 总计530对数据
lenth = min(len(sentences),len(sentences_wrong))

print("読みやすい文：",len(sentences))
print("読みにくい文：",len(sentences_wrong))

correct = []
wrong = []

for i in range(len(sentences)):
  for j in range(len(sentences_wrong)):
    if dic_correct[i][1] == dic_wrong[j][1]:  
      correct.append(sentences[i])
      wrong.append(sentences_wrong[j])
# Out:
# 読みやすい文： 530
# 読みにくい文： 546

# %%
# 根据正确文 改变 错误问的.tag  REDUCE  SWAP 
# 2.0

def algo(wrong,correct):
  dic2 = {}

  for i in range(lenth):

    for j in range(len(wrong[i])):
      if wrong[i][j].trim_phrase not in dic2:
        dic2[wrong[i][j].trim_phrase] = [] 
      dic2[wrong[i][j].trim_phrase].append(j)


    for j in range(len(correct[i])):
      if j == len(correct[i])-1:
        break

      for m in range(len(dic2[correct[i][j].trim_phrase])):
        for n in range(len(dic2[correct[i][j+1].trim_phrase])):
          if correct[i][j].dst == j+1 and dic2[correct[i][j].trim_phrase][m] == dic2[correct[i][j+1].trim_phrase][n] - 1:
            wrong[i][dic2[correct[i][j].trim_phrase][m]].tag = "REDUCE"
            correct[i][j].tag = "REDUCE"
            if correct[i][j].phrase[-1] == '、':
              wrong[i][dic2[correct[i][j].trim_phrase][m]].tag = "REDUCE_COMMA"
              correct[i][j].tag = "REDUCE_COMMA"

          if dic2[correct[i][j].trim_phrase][m] < len(wrong[i])-1 and dic2[correct[i][j].trim_phrase][m] == dic2[correct[i][j+1].trim_phrase][n] + 1:
            if wrong[i][dic2[correct[i][j].trim_phrase][m]].tag == 'KEEP':  
              wrong[i][dic2[correct[i][j].trim_phrase][m]].tag = "SWAP_B"
              wrong[i][dic2[correct[i][j+1].trim_phrase][n]].tag = "SWAP_F"
            else:
              continue

          if j + 3 < len(correct[i]) and dic2[correct[i][j].trim_phrase][m] - 2 >= 0:
            if wrong[i][dic2[correct[i][j].trim_phrase][m]].tag == 'KEEP' and wrong[i][dic2[correct[i][j].trim_phrase][m]-1].tag == 'KEEP' and wrong[i][dic2[correct[i][j].trim_phrase][m]-2].tag == 'KEEP':
              if correct[i][j].dst == correct[i][j+1].dst == correct[i][j+2].dst:
                if correct[i][j+1].trim_phrase == wrong[i][dic2[correct[i][j].trim_phrase][m]-2].trim_phrase and correct[i][j+2].trim_phrase == wrong[i][dic2[correct[i][j].trim_phrase][m]-1].trim_phrase:
                  wrong[i][dic2[correct[i][j].trim_phrase][m]-1].tag = "SWAP_F"
                  wrong[i][dic2[correct[i][j].trim_phrase][m]].tag = "SWAP_B"

          if j + 3 < len(correct[i]) and dic2[correct[i][j].trim_phrase][m] - 1 >= 0 and dic2[correct[i][j].trim_phrase][m] + 2 < len(correct[i]):
            if wrong[i][dic2[correct[i][j].trim_phrase][m]].tag == 'KEEP' and wrong[i][dic2[correct[i][j].trim_phrase][m]-1].tag == 'KEEP' and wrong[i][dic2[correct[i][j].trim_phrase][m]+1].tag == 'KEEP':
              if correct[i][j].dst == correct[i][j+1].dst == correct[i][j+2].dst:
                if correct[i][j+1].trim_phrase == wrong[i][dic2[correct[i][j].trim_phrase][m]+1].trim_phrase and correct[i][j+2].trim_phrase == wrong[i][dic2[correct[i][j].trim_phrase][m]-1].trim_phrase:
                  wrong[i][dic2[correct[i][j].trim_phrase][m]-1].tag = "SWAP_F"
                  wrong[i][dic2[correct[i][j].trim_phrase][m]].tag = "SWAP_B"
          


    dic2 = {}

# %%
# main
algo(wrong,correct) # step1_tag

# %%
# step1_tag wrong結果確認
for i in range(515,516):
  print("-------  sentence ", i+1, "-------")
  for j, chunk in enumerate(wrong[i]):
    print('{}: {}: {}'.format(j, wrong[i][j].trim_phrase, wrong[i][j].tag))
# Out:
# -------  sentence  516 -------
# 0: 工事を: KEEP
# 1: この: REDUCE
# 2: 土地の: REDUCE
# 3: 建物部分だけを: REDUCE
# 4: 残して: KEEP
# 5: 今年: REDUCE
# 6: 三月を: REDUCE
# 7: めどに: KEEP
# 8: 完成させる: REDUCE
# 9: ことに: KEEP
# 10: この: SWAP_F
# 11: ため: SWAP_B
# 12: している。: KEEP

# %%
# 修正重复词 无法对应 问题  例:この
wrong[41][3].tag = 'KEEP'

wrong[124][6].tag = 'REDUCE'
wrong[124][7].tag = 'KEEP'

wrong[515][10].tag = 'REDUCE'
wrong[515][11].tag = 'KEEP'

# %%
# step1_tag correct結果確認
for i in range(100):
  print("-------  sentence ", i+1, "-------")
  for j, chunk in enumerate(correct[i]):
    print('{}: {}: {}: {}: {}'.format(j, chunk.trim_phrase, chunk.tag, chunk.dst, chunk.phrase))
# Out:
# -------  sentence  1 -------
# 0: 同社では: KEEP: 5: 同社では
# 1: すでに: KEEP: 5: すでに
# 2: 準役員クラス以上に: KEEP: 5: 準役員クラス以上に
# -------  sentence  98 -------
# 0: もし: KEEP: 5: もし
# 1: 大都市で: KEEP: 5: 大都市で、
# 2: 震度６を: REDUCE: 3: 震度６を
# 3: 超える: REDUCE: 4: 超える
# 4: 地震が: KEEP: 5: 地震が
# 5: 起きたら: KEEP: 7: 起きたら
# 6: どう: REDUCE: 7: どう
# 7: なるでしょうか。: KEEP: -1: なるでしょうか。
# -------  sentence  99 -------
# 0: 国は: KEEP: 12: 国は
# 1: 国民の: REDUCE: 2: 国民の
# 2: 生命を: REDUCE: 3: 生命を
# 3: 守る: REDUCE: 4: 守る
# 4: ために: KEEP: 12: ために、
# 5: 割れない: REDUCE: 6: 割れない
# 6: ガラス: KEEP: 9: ガラス、
# 7: 割れても: REDUCE: 8: 割れても
# 8: 飛び散らない: REDUCE: 9: 飛び散らない
# 9: ガラスの: REDUCE: 10: ガラスの
# 10: 開発に: KEEP: 12: 開発に
# 11: 予算を: KEEP: 12: 予算を
# 12: 出していただけないでしょうか。: KEEP: -1: 出していただけないでしょうか。
# -------  sentence  100 -------
# 0: また: KEEP: 12: また、
# 1: 開発されるまで: KEEP: 12: 開発されるまで、
# 2: せめて: KEEP: 12: せめて
# 3: 道路に: REDUCE: 4: 道路に
# 4: 面する: KEEP: 6: 面する
# 5: 窓ガラスや: KEEP: 6: 窓ガラスや
# 6: 戸には: KEEP: 8: 戸には、
# 7: 飛散防止措置を: KEEP: 8: 飛散防止措置を
# 8: とる: REDUCE: 9: とる
# 9: ことを: REDUCE: 10: ことを
# 10: 義務づけ: KEEP: 12: 義務づけ、
# 11: 資金援助を: REDUCE: 12: 資金援助を
# 12: 願えないでしょうか。: KEEP: -1: 願えないでしょうか。

# %%
# 正确文的结构体
class Chunk_temp:
    def __init__(self, phrase, trim_phrase, tag ,dst):
      self.phrase = phrase
      self.trim_phrase = trim_phrase
      self.tag = tag
      self.dst = dst

# 错误文的结构体
class Wrong_chunk_temp:
    def __init__(self, trim_phrase, tag):
      self.trim_phrase = trim_phrase
      self.tag = tag

# 正确文的结构体构造 [][][] -> chunk.trim_phrase  chunk.tag   chunk.dst
class New_chunk:
    def __init__(self, new_chunk):
      self.phrase = new_chunk[0]
      self.trim_phrase = new_chunk[1]
      self.tag = new_chunk[2]
      self.dst = new_chunk[3]

    def change(self):
      chunks = []
      for i in range(len(self.dst)):
        chunks.append(Chunk_temp(self.phrase[i], self.trim_phrase[i], self.tag[i], self.dst[i]))
      return chunks

# 错误文的结构体构造 [][][] -> chunk.trim_phrase  chunk.tag
class Wrong_new_chunk:
    def __init__(self, new_chunk):
      self.trim_phrase = new_chunk[0]
      self.tag = new_chunk[1]

    def change(self):
      chunks = []
      for i in range(len(self.trim_phrase)):
        chunks.append(Wrong_chunk_temp(self.trim_phrase[i], self.tag[i]))
      return chunks


# 正确文的tag_realize算法 得到 trim_phrase, tag, dst
class Merged:
  def __init__(self, j, phrase, trim_phrase, tag, dst):
    self.j = j
    self.phrase = phrase
    self.trim_phrase = trim_phrase
    self.tag = tag
    self.dst = dst

  def merge(self):
    new_phrase = []
    new_trim_phrase = []
    new_tag = []
    index = []
    set1 = set([])
    str1 = ''
    str2 = ''
    list_dst = []
    lag = []

    for i in range(self.j):
      if self.tag[i] == 'REDUCE':
        set1.add(i)
        set1.add(i+1)

      if self.tag[i] == 'REDUCE_COMMA':
        set1.add(i)
        set1.add(i+1)
        lag.append(i)

      if self.tag[i] == 'KEEP':
        temp_list = list(set1)
        temp_list.sort()
        if len(temp_list)>0:
          list_dst.append(self.dst[temp_list[-1]])
        for i in temp_list:
          if i in lag:
            str1 += self.phrase[i]
            str1 += '、'
            str2 += self.trim_phrase[i]
            str2 += '、'
          else:
            str1 += self.phrase[i]
            str2 += self.trim_phrase[i]

        if len(str2)>0:
          new_phrase.append(str1)
          new_trim_phrase.append(str2)
          index.append(list(set1))
          new_tag.append("KEEP")
          str1 = ''
          str2 = ''
          set1.clear()
        else: 
          new_phrase.append(self.phrase[i])
          new_trim_phrase.append(self.trim_phrase[i])
          new_tag.append("KEEP")
          index.append(i)
          list_dst.append(self.dst[i])      

      if self.tag[i] == 'SWAP_F':
        new_phrase.append(self.phrase[i+1])
        new_trim_phrase.append(self.trim_phrase[i+1])
        new_tag.append("KEEP")
        index.append(i+1)
      if self.tag[i] == 'SWAP_B':
        new_phrase.append(self.phrase[i-1])
        new_trim_phrase.append(self.trim_phrase[i-1])
        new_tag.append("KEEP")
        index.append(i-1)

    new_dst = []
    for m in range(len(list_dst)):
      for n in range(len(index)):
        if isinstance(index[n],int):
          if list_dst[m] == index[n]:
            new_dst.append(n)

        else:
          for k in range(len(index[n])):
            if list_dst[m] == index[n][k]:
              new_dst.append(n)
    new_dst.append(-1)

    return new_phrase,new_trim_phrase,new_tag,new_dst

# 错误文的tag_realize算法 得到 trim_phrase, tag
class Wrong_merged:
  def __init__(self, j, trim_phrase, tag):
    self.j = j
    self.trim_phrase = trim_phrase
    self.tag = tag

  def merge(self):
    new_trim_phrase = []
    new_tag = []
    index = []
    set1 = set([])
    str1 = ''
    lag = []

    for i in range(self.j):
      if self.tag[i] == 'REDUCE':
        set1.add(i)
        set1.add(i+1)

      if self.tag[i] == 'REDUCE_COMMA':
        set1.add(i)
        set1.add(i+1)
        lag.append(i)

      if self.tag[i] == 'KEEP':
        temp_list = list(set1)
        temp_list.sort()
        for i in temp_list:
          if i in lag:
            str1 += self.trim_phrase[i]
            str1 += '、'
          else:
            str1 += self.trim_phrase[i]
        if len(str1)>0:
          new_trim_phrase.append(str1)
          index.append(list(set1))
          new_tag.append("KEEP")
          str1 = ''
          set1.clear()
        else: 
          new_trim_phrase.append(self.trim_phrase[i])
          new_tag.append("KEEP")
          index.append(i)
          
      if self.tag[i] == 'SWAP_F':
        new_trim_phrase.append(self.trim_phrase[i+1])
        new_tag.append("KEEP")
        index.append(i+1)
      if self.tag[i] == 'SWAP_B':
        new_trim_phrase.append(self.trim_phrase[i-1])
        new_tag.append("KEEP")
        index.append(i-1)

    return new_trim_phrase,new_tag

# %%
lag = []
tag = ['REDUCE','REDUCE_COMMA','REDUCE','KEEP','REDUCE_COMMA']
text = ['REDUCE1','REDUCE_COMMA1','REDUCE1','KEEP1','REDUCE_COMMA1']
list1 = [1,2,3,4]
str1 = ''
for i in range(len(tag)):
  if tag[i] ==  'REDUCE_COMMA':
    lag.append(i)
print(lag)
for i in list1:
  if i in lag:
    str1 += text[i]
    str1 += '、'
  else:
    str1 += text[i]
print(str1)
# Out:
# [1, 4]
# REDUCE_COMMA1、REDUCE1KEEP1REDUCE_COMMA1、

# %%
# 重构结构 chunk.trim_phrase  chunk.tag   chunk.dst  ->  [][][] 并调用算法
def tag_realize_algo(wrong,correct):
  phrase = []
  trim_phrase = []
  tag = []
  dst = []
  new_chunks = []
  correct_new_chunks = []

  for i in range(lenth):
    for j in range(len(wrong[i])):
      trim_phrase.append(wrong[i][j].trim_phrase)
      tag.append(wrong[i][j].tag)

    new_chunk = Wrong_merged(len(wrong[i]), trim_phrase, tag).merge()
    trim_phrase = []
    tag = []
    temp_chunk = Wrong_new_chunk(new_chunk).change()
    new_chunks.append(temp_chunk)

    for j in range(len(correct[i])):
      phrase.append(correct[i][j].phrase)
      trim_phrase.append(correct[i][j].trim_phrase)
      
      tag.append(correct[i][j].tag)
      dst.append(correct[i][j].dst)
    
    correct_new_chunk = Merged(len(correct[i]), phrase, trim_phrase, tag, dst).merge()
    phrase = []
    trim_phrase = []
    tag = []
    dst = []
    temp_correct_chunk = New_chunk(correct_new_chunk).change()
    correct_new_chunks.append(temp_correct_chunk)
  
  return new_chunks,correct_new_chunks

# %%
# main step1_realize
(new_chunks,correct_new_chunks) = tag_realize_algo(wrong,correct)

# %%
# step1_realize wrong結果確認
for i in range(41,42):
  print('------------sentence:',i+1,'----------------')
  for j in range(len(new_chunks[i])):
    print(j, new_chunks[i][j].trim_phrase, new_chunks[i][j].tag)
# Out:
# ------------sentence: 42 ----------------
# 0 常任理事国入りによって KEEP
# 1 そのことが KEEP
# 2 困難になることが想定されるならば KEEP
# 3 常任理事国入りは KEEP
# 4 慎重にすべきだと思う。 KEEP

# %%
# step1_realize correct結果確認
for i in range(41,42):
  print('------------sentence:',i+1,'----------------')
  for j in range(len(correct_new_chunks[i])):
    print(j, correct_new_chunks[i][j].trim_phrase, correct_new_chunks[i][j].tag, correct_new_chunks[i][j].dst)
# Out:
# ------------sentence: 42 ----------------
# 0 そのことが KEEP 2
# 1 常任理事国入りによって KEEP 2
# 2 困難になることが想定されるならば KEEP 4
# 3 常任理事国入りは KEEP 4
# 4 慎重にすべきだと思う。 KEEP -1

# %%
# tag and realize algorithm
for i in range(20):
  algo(new_chunks,correct_new_chunks)
  (new_chunks,correct_new_chunks) = tag_realize_algo(new_chunks,correct_new_chunks)

# %%
# wrong結果確認  # 530对数据中349对成功   490
count = 0
for i in range(lenth):
  print('------------sentence:',i+1,'----------------')
  for j in range(len(new_chunks[i])):
    print(j, new_chunks[i][j].trim_phrase, new_chunks[i][j].tag)
  if len(new_chunks[i]) == 1:
    count += 1
# Out:
# ------------sentence: 1 ----------------
# 0 同社ではすでに準役員クラス以上に能力重視型の年俸制を導入している。 KEEP
# ------------sentence: 2 ----------------
# 0 首相は、今春の統一地方選後に党全体での新党移行を目指す考えを強調、離党など性急な行動への自重を求めた。 KEEP
# ------------sentence: 3 ----------------
# 0 しかし、山花氏は二十日の通常国会召集前の新党結成を主張して物別れに終わり、同党の亀裂は決定的になった。 KEEP
# ------------sentence: 4 ----------------
# 0 山花氏は予定通り九日、準備会参加議員の一回目の集約を行う。 KEEP
# ------------sentence: 5 ----------------
# 0 しかし、準備会参加はただちに離党を意味せず、実際の離党者数が焦点になる。 KEEP
# ------------sentence: 6 ----------------
# 0 妥協案として統一地方選後に市民団体代表も交えた新党準備会を発足させる考えを示したが、歩み寄りはなかった。 KEEP
# ------------sentence: 7 ----------------
# 0 また、山花氏は通常国会で新党による新国会内会派を旗揚げしても村山政権を支える姿勢を表明。 KEEP
# ------------sentence: 8 ----------------
# 0 しかし、首相は山花氏らの行動は倒閣につながるとの考えを強調した。 KEEP
# ------------sentence: 9 ----------------
# 0 さらに首相は、訪米中に政権基盤を揺るがすような行動を取らないようくぎを刺した。 KEEP
# ------------sentence: 10 ----------------
# 0 同大統領の首都脱出は先にインタファクス通信が六日、グロズヌイの軍事筋の情報として伝えたが、ロシア政府が公式に認めたのは初めて。 KEEP
# ------------sentence: 11 ----------------
# 0 しかし、チェチェン側からこれを確認する情報は伝えられていない。 KEEP
# ------------sentence: 12 ----------------
# 0 政府発表によると、チェチェン共和国の情報機関を指揮するゲリスハノフ保安相も首都を脱出、東方のグデルメスにいるという。 KEEP
# ------------sentence: 13 ----------------
# 0 ロシア政府は先に、同保安相はロシア側に協力する意向を表明したと発表している。 KEEP
# ------------sentence: 14 ----------------
# 0 自民党道連やさきがけ北海道と政策協議の詰めを急ぎ、遅くとも十四日までに正式に表明する。 KEEP
# ------------sentence: 15 ----------------
# 0 北海道勤労者医療協会副専務理事の甲斐基男氏も KEEP
# 1 共産党推薦で KEEP
# 2 同知事選では KEEP
# 3 社会党が前副知事の堀達也氏の推薦を決め KEEP
# 4 出馬する。 KEEP
# ------------sentence: 16 ----------------
# 0 伊東氏は道政に臨む姿勢としてトップダウン方式を批判した。 KEEP
# ------------sentence: 17 ----------------
# 0 フライトレコーダーを詳細に解析し、事故機は高度五〇六メートルで急降下したが、当初指摘された墜落直前の電源切れはなく、機体の異常は確認されなかったことを明らかにした。 KEEP
# ------------sentence: 18 ----------------
# 0 事故調は、来月七日に意見聴取会を開く。 KEEP
# ------------sentence: 19 ----------------
# 0 事故直後、事故調は電源切れがなければ機体を立て直せた可能性を指摘したが、電源切れや墜落直前の再上昇はなく、機首下げ状態のまま墜落したと断定した。 KEEP
# ------------sentence: 20 ----------------
# 0 国連安保理常任理事国入りについてはいろいろな議論がある。 KEEP
# ------------sentence: 21 ----------------
# 0 戦後五十年ということでは、戦争を総括すべきだと思う。 KEEP
# ------------sentence: 22 ----------------
# 0 不毛な KEEP
# 1 戦争は KEEP
# 2 いかに KEEP
# 3 犠牲を多く出す KEEP
# 4 ものであるかを KEEP
# 5 同時に KEEP
# 6 後世に対して KEEP
# 7 伝えなければならない。 KEEP
# ------------sentence: 23 ----------------
# 0 国際社会、特に東南アジアに対して KEEP
# 1 いろいろな発言が KEEP
# 2 それをやって KEEP
# 3 初めて KEEP
# 4 日本は KEEP
# 5 できるようになる。 KEEP
# ------------sentence: 24 ----------------
# 0 しかし前文は国際社会で名誉ある地位をうたっている。 KEEP
# ------------sentence: 25 ----------------
# 0 私は軍拡論者ではないが、議論しなければシビリアンコントロールができない。 KEEP
# ------------sentence: 26 ----------------
# 0 憲法に不備や時代に合わないところがあることは認めるが、これからいよいよ使えるという部分がいっぱいある。 KEEP
# ------------sentence: 27 ----------------
# 0 湾岸戦争後の国連体制はおおむね円滑に機能し始めている。 KEEP
# ------------sentence: 28 ----------------
# 0 武器輸出の規制強化や軍縮をやりつつ国連平和維持活動をやるべきだ。 KEEP
# ------------sentence: 29 ----------------
# 0 武器輸出が放置されたままだと危険が増すばかりだから、ＰＫＯはすたれる。 KEEP
# ------------sentence: 30 ----------------
# 0 日本が先頭に立って国際社会に物を言うべきだ。 KEEP
# ------------sentence: 31 ----------------
# 0 その芽生えとしての平和維持活動は大事に育てなくてはならない。 KEEP
# ------------sentence: 32 ----------------
# 0 そのためにもＰＫＯに伴う危険を少なくしていこうという努力が先決だ。 KEEP
# ------------sentence: 33 ----------------
# 0 一番極端な九条の改正から始まって一字一句日本語を直せという文章論まで幅広い。 KEEP
# ------------sentence: 34 ----------------
# 0 論憲は、ただちに憲法改正だという人と、論じていいものを作っていこうという人がいて論憲自体の解釈が分からない。 KEEP
# ------------sentence: 35 ----------------
# 0 戦後五十年を機に、日本が新しい時代に変わっていく中で憲法の価値が改めて見直されている。 KEEP
# ------------sentence: 36 ----------------
# 0 今の日本の政党や政治家の中で具体的に改憲を主張している人はほとんどいない。 KEEP
# ------------sentence: 37 ----------------
# 0 国民の間にも憲法はかなり定着した状況にあると思う。 KEEP
# ------------sentence: 38 ----------------
# 0 憲法とかい離している現状に憲法を合わせる改憲の考え方は、国民の間には支持は少ないのではないか。 KEEP
# ------------sentence: 39 ----------------
# 0 創憲という立場は憲法の理念を肯定し、より具体化していくために考えられることだ。 KEEP
# ------------sentence: 40 ----------------
# 0 国連の安保理常任理事国になることによって、憲法よりも国連の決定に対する義務が優先するという立場に立つなら日本は自己矛盾に陥ると思う。 KEEP
# ------------sentence: 41 ----------------
# 0 憲法の範囲内ということを KEEP
# 1 あくまでも KEEP
# 2 きちんと KEEP
# 3 日本は KEEP
# 4 国連との関係において KEEP
# 5 していなくてはならない。 KEEP
# ------------sentence: 42 ----------------
# 0 そのことが常任理事国入りによって困難になることが想定されるならば、常任理事国入りは慎重にすべきだと思う。 KEEP
# ------------sentence: 43 ----------------
# 0 政界再編のうねりの中で、独自路線を進む共産党。 KEEP
# ------------sentence: 44 ----------------
# 0 今後の政局に、どう対応するのか、同党の不破哲三委員長に聞いた。 KEEP
# ------------sentence: 45 ----------------
# 0 社会党は KEEP
# 1 その意味では突然、右寄りが始まったわけではないが KEEP
# 2 一連の分野で KEEP
# 3 一定の公約を KEEP
# 4 一年前に総選挙があり KEEP
# 5 した。 KEEP
# ------------sentence: 46 ----------------
# 0 国民との関係で政党が成り立っているという根本を社会党は捨てた。 KEEP
# ------------sentence: 47 ----------------
# 0 今度は、それもない。 KEEP
# ------------sentence: 48 ----------------
# 0 それにより社会党自身の支持基盤を崩壊させた。 KEEP
# ------------sentence: 49 ----------------
# 0 それが最大の致命的矛盾だ。 KEEP
# ------------sentence: 50 ----------------
# 0 その前に分裂があるのかもしれないが、矛盾が表面化した場合には政権は持たない。 KEEP
# ------------sentence: 51 ----------------
# 0 旧野党を全部、自民党政治の側に吸収して、その中で二つに割って争い合う構想は早くからあった。 KEEP
# ------------sentence: 52 ----------------
# 0 社会党の分裂で通常国会の冒頭どうなるか。 KEEP
# ------------sentence: 53 ----------------
# 0 重大問題について、まともに国会が審議しない。 KEEP
# ------------sentence: 54 ----------------
# 0 政党支持なし層が増えているのは、現状批判がまず、そんな形で表れていると思う。 KEEP
# ------------sentence: 55 ----------------
# 0 これをいかにして政治に生かすのか。 KEEP
# ------------sentence: 56 ----------------
# 0 最近の演説会は新しい層が多いため雰囲気が違う。 KEEP
# ------------sentence: 57 ----------------
# 0 拍手も笑い声も起きないが真剣に聞いていてくれる。 KEEP
# ------------sentence: 58 ----------------
# 0 風は自分たちで起こす。 KEEP
# ------------sentence: 59 ----------------
# 0 旧野党が吸収されたことで、三分の二の壁が取り払われた。 KEEP
# ------------sentence: 60 ----------------
# 0 一応、与党と野党と席は違うが中身が変わらない勢力が国会の九割以上を占める。 KEEP
# ------------sentence: 61 ----------------
# 0 しかも小選挙区比例代表並立制というのは、苦労しないで三分の二を超える勢力を占めるのを保証する体制だ。 KEEP
# ------------sentence: 62 ----------------
# 0 戦後ずっと、自民党が三分の二を超える勢力を持てないことが、悪政がそう自由勝手に横行できない一つの壁だった。 KEEP
# ------------sentence: 63 ----------------
# 0 増強した自衛隊の海外派兵について自民党単独政権時代よりもっと自由自在にやり出している。 KEEP
# ------------sentence: 64 ----------------
# 0 今までの自民党政権だったらあからさまにできなかったことを村山政権なるがゆえに、平気でやる面が強い。 KEEP
# ------------sentence: 65 ----------------
# 0 今の改革論の中には日本の社会が一番病んでいることへの目がない。 KEEP
# ------------sentence: 66 ----------------
# 0 消費税増税が国会を通った後でも、世論調査では増税反対が三分の二の勢力だ。 KEEP
# ------------sentence: 67 ----------------
# 0 この矛盾が問題で、世論の動きからいえば、国会の中で我々のパートナーがいないのが不思議なほどだ。 KEEP
# ------------sentence: 68 ----------------
# 0 国民の中では我々の立場そのものは多数派だ。 KEEP
# ------------sentence: 69 ----------------
# 0 国民の意思に反する政治が圧倒的多数で進んでいる。 KEEP
# ------------sentence: 70 ----------------
# 0 筋が間違っていなければ変えないで頑張る値打ちが光る。 KEEP
# ------------sentence: 71 ----------------
# 0 我々の綱領は、今は資本主義の枠内で日本社会の問題点に応える民主的改革が必要だということを路線にしてきた。 KEEP
# ------------sentence: 72 ----------------
# 0 今の社会が求めている現代的方針というのはかなり前からこなしている自信がある。 KEEP
# ------------sentence: 73 ----------------
# 0 国民生活を不当に縛りあげている規制は暮らしや福祉に関して多すぎる。 KEEP
# ------------sentence: 74 ----------------
# 0 行革、地方分権についてもそういう立場で中身の論戦をしようと思う。 KEEP
# ------------sentence: 75 ----------------
# 0 村山富市首相は十日、首相就任後初めて米国を訪問し、十一日にクリントン大統領と会談する。 KEEP
# ------------sentence: 76 ----------------
# 0 戦後五十年の節目にあたり、日米の緊密な協調関係をアピールするのが最大の目的。 KEEP
# ------------sentence: 77 ----------------
# 0 首相は冷戦後の新たな日米関係づくりに向け、軍縮時代に即した日米安保体制構築や、日本経済の構造転換のための規制緩和などに積極的に取り組む考えを示す方針だ。 KEEP
# ------------sentence: 78 ----------------
# 0 今年は終戦記念行事が多い。 KEEP
# ------------sentence: 79 ----------------
# 0 訪米成果として強調し、冷戦後の新たな日米安保体制構築の足掛かりとしたい考え。 KEEP
# ------------sentence: 80 ----------------
# 0 しかし、トルーマン大統領は十七日付の書簡でクリル諸島については了承したものの、北海道北部に関する要求を拒否。 KEEP
# ------------sentence: 81 ----------------
# 0 統一地方選前に新党を結成しなければ、新進党との選挙協力も含めて勢力結集の展望がなくなる山花氏側と、ある程度の離党はやむを得ないと考える首相の違いがくっきりと表れた会談となった。 KEEP
# ------------sentence: 82 ----------------
# 0 山花氏が四月の統一地方選前の新党結成を譲らない背景には、新民連急進派議員の多くが、新進党との選挙協力を目指している点にある。 KEEP
# ------------sentence: 83 ----------------
# 0 新進党が次期衆院選の第一次公認候補を発表すれば、その後、連携を探ることは困難になる。 KEEP
# ------------sentence: 84 ----------------
# 0 この点で、両者のミゾは埋まりようがなかった。 KEEP
# ------------sentence: 85 ----------------
# 0 今後、首相は社会党とさきがけの連携を強化することで、新勢力結集の動きを具体化したい考え。 KEEP
# ------------sentence: 86 ----------------
# 0 山花氏らの動きや連鎖反応をある程度は封じ込めることが可能との見通しもあり、決裂が予想される会談に臨んだとみられる。 KEEP
# ------------sentence: 87 ----------------
# 0 こうした事情があるにもかかわらず、山花氏が久保亘書記長の仲介に応じる形で、党首である首相との会談に応じたのは、新党活動本格化の前に一応の区切りをつけることは避けられないとの判断もあった。 KEEP
# ------------sentence: 88 ----------------
# 0 日本の国連安保理常任理事国入りに対して国民の半数以上が賛成した一方、国連平和維持活動には現在以上の積極参加を望んでいる人は少数にとどまった。 KEEP
# ------------sentence: 89 ----------------
# 0 調査は昨年十月、全国の二十歳以上の男女三千人を対象に実施、有効回収率は六八・七％。 KEEP
# ------------sentence: 90 ----------------
# 0 古くから日記文学が花開き、その伝統は連綿と続く。 KEEP
# ------------sentence: 91 ----------------
# 0 創業者の大橋佐平は五十歳で、新潟の長岡から上京、博文館を起こした。 KEEP
# ------------sentence: 92 ----------------
# 0 佐平は海外事情にも明るく、戊辰戦争では恭順派。 KEEP
# ------------sentence: 93 ----------------
# 0 その主人公、小林虎三郎とも親交があった。 KEEP
# ------------sentence: 94 ----------------
# 0 書籍型日記の不動の定番だ。 KEEP
# ------------sentence: 95 ----------------
# 0 あの日の、庶民の偽りのない記録に日記の重みを痛切に感じた。 KEEP
# ------------sentence: 96 ----------------
# 0 三陸はるか沖地震で被災された方々に、心からお見舞いを申し上げます。 KEEP
# ------------sentence: 97 ----------------
# 0 飛散防止シートを KEEP
# 1 我が家は KEEP
# 2 マンションの十階なので KEEP
# 3 強風対策も兼ねて KEEP
# 4 ドアのガラスなどには KEEP
# 5 張っています。 KEEP
# ------------sentence: 98 ----------------
# 0 もし大都市で、震度６を超える地震が起きたらどうなるでしょうか。 KEEP
# ------------sentence: 99 ----------------
# 0 国は国民の生命を守るために、割れないガラス、割れても飛び散らないガラスの開発に予算を出していただけないでしょうか。 KEEP
# ------------sentence: 100 ----------------
# 0 また、開発されるまで、せめて道路に面する窓ガラスや戸には、飛散防止措置をとることを義務づけ、資金援助を願えないでしょうか。 KEEP
# ------------sentence: 101 ----------------
# 0 雨あられと降るガラスの破片で多くの死傷者を出す前に、地震国、日本としての賢明な対策を政府にお願いします。 KEEP
# ------------sentence: 102 ----------------
# 0 司法修習生に冒頭陳述をさせていたという本紙の報道に敬意を表したい。 KEEP
# ------------sentence: 103 ----------------
# 0 私の知人に裁判官への任官を拒否された当事者がいて、彼から直接聞いたことがある。 KEEP
# ------------sentence: 104 ----------------
# 0 どうも、化学の実験学習程度の認識しか、司法当局者にはないらしい。 KEEP
# ------------sentence: 105 ----------------
# 0 彼の人権は、最も人権を守るべき立場にある者によって侵されたのだ。 KEEP
# ------------sentence: 106 ----------------
# 0 その責任はだれが負うのか。 KEEP
# ------------sentence: 107 ----------------
# 0 先日、有料で兵器を使用することができるというツアーのことを、テレビで知った。 KEEP
# ------------sentence: 108 ----------------
# 0 もちろん、日本国内ではないが、反感を持たずにはいられなかった。 KEEP
# ------------sentence: 109 ----------------
# 0 戦争につながる兵器が、安易に金もうけに使用されている場面を、戦争で苦労した人は、どのような気持ちで見ていたのであろうか。 KEEP
# ------------sentence: 110 ----------------
# 0 戦後、長い年月が経過したので、戦争が美化されてきてしまう部分も少なからずあると思う。 KEEP
# ------------sentence: 111 ----------------
# 0 兵器に触れることが、なぜツアーになるのであろうか。 KEEP
# ------------sentence: 112 ----------------
# 0 日本でも、今日、平和すぎて、戦争の恐ろしさや平和のありがたさについて、深く考える機会が少ないのではないのだろうか。 KEEP
# ------------sentence: 113 ----------------
# 0 教科書にも、最小限のことしか記載されていない。 KEEP
# ------------sentence: 114 ----------------
# 0 私自身、戦争を体験したことはないが、いつの世代も戦争を美化すべきではないと思う。 KEEP
# ------------sentence: 115 ----------------
# 0 私はむやみに人を殺して人肉を食する民族は存在しないと思う。 KEEP
# ------------sentence: 116 ----------------
# 0 以前、首を狩る慣習を持っていた民族にしても、その慣習には儀礼的な意味づけがあるのだ。 KEEP
# ------------sentence: 117 ----------------
# 0 日本の武士も KEEP
# 1 それに KEEP
# 2 武名を KEEP
# 3 昔は KEEP
# 4 敵の首をかき切って KEEP
# 5 あげていたではないか。 KEEP
# ------------sentence: 118 ----------------
# 0 熱帯では、汗を流して洋服を着るよりも、裸の方が合理的であろう。 KEEP
# ------------sentence: 119 ----------------
# 0 洋服を着るということは、進歩のあかしであるのだろうか。 KEEP
# ------------sentence: 120 ----------------
# 0 これは多くの女性が、男性の氏を名乗る、現代の結婚に起因していると考える。 KEEP
# ------------sentence: 121 ----------------
# 0 世の女性はもっと姓に対する関心を示してほしいものだ。 KEEP
# ------------sentence: 122 ----------------
# 0 夫婦別姓に対する総理府の調査では、半数以上が反対だという。 KEEP
# ------------sentence: 123 ----------------
# 0 それなら、女性は、自分が生まれた時からの氏が消えてもいいと思っているのだろうか。 KEEP
# ------------sentence: 124 ----------------
# 0 都道府県議会議員の海外視察に、年間十億円近い公費がつぎ込まれているという。 KEEP
# ------------sentence: 125 ----------------
# 0 何を KEEP
# 1 このお金は、国民の税金から賄われているのだが KEEP
# 2 議員たちは KEEP
# 3 視察で KEEP
# 4 何を見 KEEP
# 5 学んできたのだろうか。 KEEP
# ------------sentence: 126 ----------------
# 0 これでは無駄遣いと言われても仕方ないのではないか。 KEEP
# ------------sentence: 127 ----------------
# 0 最も興味を覚えたのは、サッチャー前首相とのあつれきである。 KEEP
# ------------sentence: 128 ----------------
# 0 そのとき彼は、首相の怒り狂った反応にびっくりした。 KEEP
# ------------sentence: 129 ----------------
# 0 彼の首相に対する不信は KEEP
# 1 八九年 KEEP
# 2 一層 KEEP
# 3 首相が KEEP
# 4 彼に KEEP
# 5 事前に KEEP
# 6 マドリードでのＥＣ首脳会議で KEEP
# 7 ＥＲＭに対する英国の方針を説明した時 KEEP
# 8 知らせなかったことで KEEP
# 9 深まる。 KEEP
# ------------sentence: 130 ----------------
# 0 政策の相違が、人格的衝突に発展した。 KEEP
# ------------sentence: 131 ----------------
# 0 二人の仲が最悪となったころ、閣議室で閣僚と科学者との会合があった。 KEEP
# ------------sentence: 132 ----------------
# 0 事を荒立てたくなかったのか、ハウ氏はいすを持ち出して、その上に乗って窓を開けたのである。 KEEP
# ------------sentence: 133 ----------------
# 0 サッチャー氏自身、回顧録の中でいみじくも言っている。 KEEP
# ------------sentence: 134 ----------------
# 0 政策についてだけでなく、人格的に傷つけられたハウ氏は、副首相という名目的地位を辞任した後、議会で辞任理由を説明する演説を行った。 KEEP
# ------------sentence: 135 ----------------
# 0 サッチャー首相の政策の狭量さ、独善を鋭く突いたこの演説こそ、サッチャー首相が首相の座から転げ落ちる推進力となった。 KEEP
# ------------sentence: 136 ----------------
# 0 彼女の人格が自らの墓穴を掘った。 KEEP
# ------------sentence: 137 ----------------
# 0 不法移民防止のため建設された高さ三メートルもある鉄板の壁の向こう側は米国だ。 KEEP
# ------------sentence: 138 ----------------
# 0 かつては米サンディエゴに司令部を置く米第三艦隊の兵士向けの歓楽街。 KEEP
# ------------sentence: 139 ----------------
# 0 それがマキラドーラ政策で、五十万人の雇用を生み出す工業都市に生まれ変わった。 KEEP
# ------------sentence: 140 ----------------
# 0 操業中の企業は現在約二千二百社。 KEEP
# ------------sentence: 141 ----------------
# 0 北米自由貿易協定の発効で進出ラッシュは今も続いている。 KEEP
# ------------sentence: 142 ----------------
# 0 米国への不法越境を目指し、全国から若者が集まってくるからだ。 KEEP
# ------------sentence: 143 ----------------
# 0 市街を見下ろす山肌にはぎっしりスラムが形成されている。 KEEP
# ------------sentence: 144 ----------------
# 0 人口は急増し推定で百五十万人。 KEEP
# ------------sentence: 145 ----------------
# 0 三年前から KEEP
# 1 二つ KEEP
# 2 アンヘラさんも KEEP
# 3 四十五人のクラスを KEEP
# 4 受け持っている。 KEEP
# ------------sentence: 146 ----------------
# 0 夫フランシスコさんは五年前、十七歳でやってきた。 KEEP
# ------------sentence: 147 ----------------
# 0 米国にあこがれ家を飛び出した。 KEEP
# ------------sentence: 148 ----------------
# 0 だが、彼はティファナにとどまった。 KEEP
# ------------sentence: 149 ----------------
# 0 何もない故郷の生活に比べれば、ここでも暮らしていける。 KEEP
# ------------sentence: 150 ----------------
# 0 運よく米系の家具工場に就職し、週二百ペソの収入。 KEEP
# ------------sentence: 151 ----------------
# 0 アンヘラさんの半月で五百ペソの給料と合わせ KEEP
# 1 念願の家を KEEP
# 2 四年前に結婚し KEEP
# 3 昨春 KEEP
# 4 購入した。 KEEP
# ------------sentence: 152 ----------------
# 0 とどまる人もいるが、米国を目指す人の波は絶えない。 KEEP
# ------------sentence: 153 ----------------
# 0 賃金が六倍も高いからだ。 KEEP
# ------------sentence: 154 ----------------
# 0 マキラドーラ工場ではメキシコの最低賃金の倍近い給与を払っているが、離職率は毎月一〇％。 KEEP
# ------------sentence: 155 ----------------
# 0 ある工場の現場主任によると、辞めていった人の大半は国境を越えたという。 KEEP
# ------------sentence: 156 ----------------
# 0 越境前の生活費を得るため、麻薬売買にも手を出す。 KEEP
# ------------sentence: 157 ----------------
# 0 ペソ暴落で強くなったドルに物を言わせて街を歩く米国人観光客をレオンさんはせん望の目で見つめる。 KEEP
# ------------sentence: 158 ----------------
# 0 ＮＡＦＴＡの恩恵を受けない人にとって、壁の向こうは夢の国だ。 KEEP
# ------------sentence: 159 ----------------
# 0 国境の南の街は夢の国への通用門でもある。 KEEP
# ------------sentence: 160 ----------------
# 0 協定は、双方部隊が午前零時の位置をもって前進を停止するというもの。 KEEP
# ------------sentence: 161 ----------------
# 0 十四日には KEEP
# 1 三回目の和平予備交渉が KEEP
# 2 ゲリラの根拠地ジャフナ半島で KEEP
# 3 停戦は二週間続き KEEP
# 4 開かれる。 KEEP
# ------------sentence: 162 ----------------
# 0 コロンボのクマラトゥンガ大統領は包括和平案の提出を明言しており、ＬＴＴＥ側は提案の中身に注目している。 KEEP
# ------------sentence: 163 ----------------
# 0 インタファクス通信によるとロシア南部イングーシ共和国のアウシェフ大統領は八日、チェチェン紛争に関する緊急会議を十一日、モスクワで開くよう近隣の北カフカス地方の各首脳らに呼び掛けた。 KEEP
# ------------sentence: 164 ----------------
# 0 ケニアの首都ナイロビで事態打開のための会議を開き KEEP
# 1 二百万人以上のルワンダ難民を抱えるルワンダ周辺の七カ国首脳は KEEP
# 2 難民がキャンプからルワンダ国内に帰還できるよう安全ルートを確保することで KEEP
# 3 七日 KEEP
# 4 合意した。 KEEP
# ------------sentence: 165 ----------------
# 0 しかし、合意の実施は裏付けのないまま終わった。 KEEP
# ------------sentence: 166 ----------------
# 0 ナイロビからの報道によると、各首脳は難民キャンプ内の旧政府軍人数万人を他の一般難民から分離し、祖国帰還希望者のために輸送手段などを提供することで合意。 KEEP
# ------------sentence: 167 ----------------
# 0 ルワンダ国内でも帰還が促進されるよう安全ルートを設定するとした。 KEEP
# ------------sentence: 168 ----------------
# 0 しかし、発表されたコミュニケにはだれが同ルートの安全と輸送手段を提供するかの記載がない。 KEEP
# ------------sentence: 169 ----------------
# 0 ボスニアの四カ月停戦協定が一日に発効して以来、北西部ビハチを除く各地は平穏だったが、協定違反の戦闘拡大の懸念が生まれている。 KEEP
# ------------sentence: 170 ----------------
# 0 今月に入ってセルビア人、クロアチア人両勢力間の戦闘が伝えられたのは初めて。 KEEP
# ------------sentence: 171 ----------------
# 0 コペンハーゲンからの報道によると、デンマーク政府は七日、チェチェン紛争への軍事介入を理由に、昨年九月に結んだロシアとの軍事協力協定を一時的に凍結した。 KEEP
# ------------sentence: 172 ----------------
# 0 デンマークは欧州連合に対し、ロシアに対する政治的制裁措置をとるよう要求している。 KEEP
# ------------sentence: 173 ----------------
# 0 チェチェン共和国の首都グロズヌイ制圧を目指すロシア軍は八日、引き続き激しい砲撃を展開し、大統領官邸のある中心部を死守するドゥダエフ政権部隊と交戦した。 KEEP
# ------------sentence: 174 ----------------
# 0 同共和国のドゥダエフ大統領が南部山岳地帯の予備司令部に避難しているとの情報があり、これを狙った作戦とみられる。 KEEP
# ------------sentence: 175 ----------------
# 0 四月二十三日に第一回投票、五月七日に第二回投票が行われる、仏大統領選挙をめぐる立候補者の最終的な絞り込み作業が、年明けとともに白熱してきた。 KEEP
# ------------sentence: 176 ----------------
# 0 保守、中道が乱立傾向を示す一方、ドロール欧州連合委員長の不出馬で、意気消沈する左翼陣営は土壇場の対応を迫られている。 KEEP
# ------------sentence: 177 ----------------
# 0 同大統領選に今のところ、正式な出馬表明をしているのは、ドゴール主義の継承を掲げる保守の共和国連合のシラク元首相ら四人。 KEEP
# ------------sentence: 178 ----------------
# 0 ザグレブからの報道によると、旧ユーゴ紛争地域で人道援助活動に従事する国連機関の輸送車の盗難事件が多発。 KEEP
# ------------sentence: 179 ----------------
# 0 編集者として数々のユニークな企画を打ち出しまたインタビューの名手としても名高い。 KEEP
# ------------sentence: 180 ----------------
# 0 世界七不思議の一つのロードス島の高さ三〇メートルの青銅神像を作ったのは、リンドスのカレスという人物だった。 KEEP
# ------------sentence: 181 ----------------
# 0 この人は八頭身の理想的男性像を作った彫刻家リュシッポスの弟子だったという。 KEEP
# ------------sentence: 182 ----------------
# 0 それが、専門家ならずとも手軽に調べられるようになったわけだが、訳者によれば特に工芸家や彫刻家らについては、邦訳されている他の文献ではわからない情報を仕入れることが出来るという。 KEEP
# ------------sentence: 183 ----------------
# 0 素人としては、別に知らなくても困らないが、ちょっと分かればうれしい話のタネが、いっぱい詰め込まれている事典といえそうだ。 KEEP
# ------------sentence: 184 ----------------
# 0 昭和のはじめ、富士八湖のひとつ四尾連湖畔の丸木小屋に移り住んだ野澤一。 KEEP
# ------------sentence: 185 ----------------
# 0 桂月は別にして他は近年忘れられた文学者が多い。 KEEP
# ------------sentence: 186 ----------------
# 0 目を輝かせながら KEEP
# 1 彼らを KEEP
# 2 著者は KEEP
# 3 森のなかに清流を発見したように KEEP
# 4 語っている。 KEEP
# ------------sentence: 187 ----------------
# 0 各巻を思想、産業、生活、風俗、信仰の五つの基軸と特論で構成。 KEEP
# ------------sentence: 188 ----------------
# 0 林屋代表が全巻の総論を執筆している。 KEEP
# ------------sentence: 189 ----------------
# 0 九二年十月、心臓発作のため急逝。 KEEP
# ------------sentence: 190 ----------------
# 0 第二部は情報公開、地球環境、コメの自由化、消費税など七つの主要問題領域の論稿を収録している。 KEEP
# ------------sentence: 191 ----------------
# 0 そのときのライスカレーに福神漬がついていたのかどうか。 KEEP
# ------------sentence: 192 ----------------
# 0 それではハヤシライスはどうして始まったのか。 KEEP
# ------------sentence: 193 ----------------
# 0 このようにライスカレーについてのおもしろい話題がいっぱい詰まっていて読者を楽しませるが、それだけではない。 KEEP
# ------------sentence: 194 ----------------
# 0 日本人の外国文化への好奇心がいきいきと描かれていて見事である。 KEEP
# ------------sentence: 195 ----------------
# 0 初めて眼鏡をかける時は少し気になる。 KEEP
# ------------sentence: 196 ----------------
# 0 わたしはまだ若いとためらうが、とにかく買った眼鏡はしゃれてるし、ぴったりだと思う。 KEEP
# ------------sentence: 197 ----------------
# 0 最初眼鏡がみせてくれるものが信じられなかった。 KEEP
# ------------sentence: 198 ----------------
# 0 拡大され、真実そのものが発言する現実に、あなたはうんざりする。 KEEP
# ------------sentence: 199 ----------------
# 0 やはり夢の十日間。 KEEP
# ------------sentence: 200 ----------------
# 0 だが夢は三日と続かなかった。 KEEP
# ------------sentence: 201 ----------------
# 0 マラナス人民統一戦線が革命を起こし、夢の島は収容所群島に変わる。 KEEP
# ------------sentence: 202 ----------------
# 0 文明はもろく、しゃれた眼鏡は曇ってしまい、あなたたち二十人は拡大されない等身大の人間ドラマを演じる。 KEEP
# ------------sentence: 203 ----------------
# 0 雪深い里での中学時代が、数々のエピソードの中で熱く回想されていた。 KEEP
# ------------sentence: 204 ----------------
# 0 あれほど刻明に想い出が描けるのは、やはり絵筆をとる人間特有の、イメージで記憶する癖が体に染みついているためだろう。 KEEP
# ------------sentence: 205 ----------------
# 0 私には、中学時代の日々の姿は老眼鏡をはずして見る活字ほども鮮明でないのに。 KEEP
# ------------sentence: 206 ----------------
# 0 著者の漫画には、家族や友人や働く人への思いやりに溢れていて、悪人が出てこない。 KEEP
# ------------sentence: 207 ----------------
# 0 みんな一生懸命に生きているからだ。 KEEP
# ------------sentence: 208 ----------------
# 0 それは、著者が働きながら貧しさを通り抜けてきたからだと思う。 KEEP
# ------------sentence: 209 ----------------
# 0 子供たちと話しながら、家族で楽しんで欲しい本だ。 KEEP
# ------------sentence: 210 ----------------
# 0 だが、繊維一つとっても、両国間での製品にそんな差があるわけではない。 KEEP
# ------------sentence: 211 ----------------
# 0 東西融合のこの超競争時代に、いまや高コスト国の日本はどのように生き残ればよいか。 KEEP
# ------------sentence: 212 ----------------
# 0 競争と雇用のジレンマをどのように解決するか。 KEEP
# ------------sentence: 213 ----------------
# 0 政府のいろんな審議会に加わっているため、産業別の雇用シミュレーションによる試算が多数盛り込まれ、内容がより具体的になっているのが特色だ。 KEEP
# ------------sentence: 214 ----------------
# 0 もちろん政府主導のシナリオが、本当に実効性を持ち得るかは疑問だろう。 KEEP
# ------------sentence: 215 ----------------
# 0 もう政府が引っぱっていく時代は終わった。 KEEP
# ------------sentence: 216 ----------------
# 0 そのため、国内の創造力をどう生かすかに、焦点を絞った方がよいと思われる。 KEEP
# ------------sentence: 217 ----------------
# 0 冒頭のニューオーリンズで本屋に入った著者は買いたい本をたくさん見つけたので、東京へ送ってもらえないかと聞く。 KEEP
# ------------sentence: 218 ----------------
# 0 ところが店員はトウキョーを知らなかった。 KEEP
# ------------sentence: 219 ----------------
# 0 河口近くのニューオーリンズから中西部へ向けてさかのぼる旅に出た著者は行く先ざきで新たな見聞に出会い、忘れていた歴史を再確認する。 KEEP
# ------------sentence: 220 ----------------
# 0 例えばニューオーリンズのあるルイジアナ州は一八〇三年までフランス領だった。 KEEP
# ------------sentence: 221 ----------------
# 0 編集長を最後に三十年勤めた同社を退職。 KEEP
# ------------sentence: 222 ----------------
# 0 現在も他の出版社の編集長を務め、こだわりの精神に変わりはない。 KEEP
# ------------sentence: 223 ----------------
# 0 温顔に笑みを浮かべながら、いつしか苦笑いに。 KEEP
# ------------sentence: 224 ----------------
# 0 この手の見直しは次の時代の見取り図をどう描くのかという大問題と連動しているだけに、いっそう論争的なテーマです。 KEEP
# ------------sentence: 225 ----------------
# 0 私は KEEP
# 1 八十歳になって KEEP
# 2 ドイツ語を KEEP
# 3 六十の手習いという言葉は聞いたことはあったが KEEP
# 4 勉強するようになった。 KEEP
# ------------sentence: 226 ----------------
# 0 ドイツ人の奥さん方八人が着物を縫いたいと言い出し、ふとしたことから私が教えることになったのがきっかけ。 KEEP
# ------------sentence: 227 ----------------
# 0 初めの二カ月だけは通訳の方に助けられたが、その後は片言の英語も通じない。 KEEP
# ------------sentence: 228 ----------------
# 0 彼女らの日本語と私のドイツ語とが何とか組み合わされて、一枚を仕立てあげるとまた次を縫って和服づくりが大いに気に入ったよう。 KEEP
# ------------sentence: 229 ----------------
# 0 クリスマスには故国のお母さんや姉妹にプレゼントするので、それぞれが二枚、三枚と作った。 KEEP
# ------------sentence: 230 ----------------
# 0 私の操る言葉もなんとか分かってくれるらしく、肩を両手で抱き締めたり、握手をしたりする。 KEEP
# ------------sentence: 231 ----------------
# 0 時間前に立つ気合十分の立ち合い。 KEEP
# ------------sentence: 232 ----------------
# 0 元大関が平幕で意欲を持って取り続けることの難しさを、チラリとのぞかせた。 KEEP
# ------------sentence: 233 ----------------
# 0 土俵際、武双山の上手投げに右ひじから倒れた貴乃花。 KEEP
# ------------sentence: 234 ----------------
# 0 勢い余って勝ち残りで土俵下に座っている曙のひざに転落した。 KEEP
# ------------sentence: 235 ----------------
# 0 普段なら番狂わせに座布団が乱舞する館内が、この日はほんの数枚が飛んだだけ。 KEEP
# ------------sentence: 236 ----------------
# 0 過去名だたる横綱たちが新横綱の初日に敗れた。 KEEP
# ------------sentence: 237 ----------------
# 0 その意気込みが十分に表れた立ち合いだった。 KEEP
# ------------sentence: 238 ----------------
# 0 貴乃花も踏み込み、左で下手を取った。 KEEP
# ------------sentence: 239 ----------------
# 0 が、この日の武双山は二の矢も厳しく、突っ張られて左わきの締めが甘くなった。 KEEP
# ------------sentence: 240 ----------------
# 0 だから、武双山が左に体を開いて投げを打つと、まわしから手が離れてしまった。 KEEP
# ------------sentence: 241 ----------------
# 0 貴乃花は淡々と、気がせいていたことを認めた。 KEEP
# ------------sentence: 242 ----------------
# 0 貴乃花も参列したが、是が非でも勝たなければという意識が取り口に微妙に影響したのかもしれない。 KEEP
# ------------sentence: 243 ----------------
# 0 連勝が途切れた悔しさをグッとこらえ、記者の質問に丁寧に応じた。 KEEP
# ------------sentence: 244 ----------------
# 0 大関時代は気分転換が苦手とされた貴乃花。 KEEP
# ------------sentence: 245 ----------------
# 0 披露宴後、会見した野茂は、九日に３回目の交渉を持つことを明らかにした。 KEEP
# ------------sentence: 246 ----------------
# 0 日本リーグの６チームと明大、東洋大の学生代表を加えた８チームがトーナメントで戦うが、コクド、新王子製紙を中心にした戦いが予想される。 KEEP
# ------------sentence: 247 ----------------
# 0 それが、６試合で２３得点。 KEEP
# ------------sentence: 248 ----------------
# 0 セットプレーを軸に KEEP
# 1 攻撃でも KEEP
# 2 自分たちの形を KEEP
# 3 圧倒的な強さで初の頂点に立ったのは KEEP
# 4 作り上げたからだった。 KEEP
# ------------sentence: 249 ----------------
# 0 前日のミーティングで、相手ＧＫのポジションが下がり気味なのを確認したうえでのサインプレーだった。 KEEP
# ------------sentence: 250 ----------------
# 0 ２人のキックを見事にゴールに結びつけたのは、森崎嘉の決定力だ。 KEEP
# ------------sentence: 251 ----------------
# 0 決勝戦では珍しいハットトリックで、今大会の得点王にもなった。 KEEP
# ------------sentence: 252 ----------------
# 0 森崎嘉は、３年前の準決勝で帝京に敗れた市船を見て、入学を決意したという。 KEEP
# ------------sentence: 253 ----------------
# 0 高校最後の大会で、帝京を自らのゴールで倒したうえ、攻撃力あるチームへ脱皮する原動力となった。 KEEP
# ------------sentence: 254 ----------------
# 0 立ち上がりの帝京はテンポの速い、多彩なパスワークで主導権を握った。 KEEP
# ------------sentence: 255 ----------------
# 0 市船の中盤のチェックは遅れがち。 KEEP
# ------------sentence: 256 ----------------
# 0 スペースを与えると帝京の個人技はさえる。 KEEP
# ------------sentence: 257 ----------------
# 0 市船は守勢になり、ロングキックでしのぐばかりだった。 KEEP
# ------------sentence: 258 ----------------
# 0 ところが、１０分も過ぎると、帝京のＤＦラインの押し上げが落ちてしまった。 KEEP
# ------------sentence: 259 ----------------
# 0 こうなると速いテンポのパスはできず、帝京は攻撃のリズムが消え、強引な個人技に頼るばかり。 KEEP
# ------------sentence: 260 ----------------
# 0 市船の前半の２点はＣＫとセンタリングからだったが、後半はＤＦラインを破っている。 KEEP
# ------------sentence: 261 ----------------
# 0 その点では、決勝に残った両チームはパスをつなぎ、サイドをえぐろうという意図を持った攻撃が見られ、一歩前進と言えよう。 KEEP
# ------------sentence: 262 ----------------
# 0 高校サッカーも中盤のプレスが厳しくなった。 KEEP
# ------------sentence: 263 ----------------
# 0 危険を避け、ロングキックで勝敗を争っている傾向が強い。 KEEP
# ------------sentence: 264 ----------------
# 0 全試合を見たわけではないが、ゲームの展開が楽しめたのは決勝ぐらいだった。 KEEP
# ------------sentence: 265 ----------------
# 0 中間の休みが２日増えて極端に動きが落ちるゲームはなくなったが、もう一段高い質を求めるならば、隔日開催は欠かせない条件だろう。 KEEP
# ------------sentence: 266 ----------------
# 0 大阪から上京した初代当主、故神戸清次郎が今川焼きにヒントを得て創案したのが、そもそもの始まり。 KEEP
# ------------sentence: 267 ----------------
# 0 あんを作るのにたっぷり八時間はかかる。 KEEP
# ------------sentence: 268 ----------------
# 0 再び、かまに戻して二時間ほど煮て沸騰したら、砂糖と塩を入れる。 KEEP
# ------------sentence: 269 ----------------
# 0 火を細めて小豆に砂糖を含ませた後、木のへらで約二時間掛けて練り上げる。 KEEP
# ------------sentence: 270 ----------------
# 0 だが山頭火は大酒のみで仕事はせず、さらに実家が始めた酒造業の倒産が重なって熊本へ夫婦で移住することに。 KEEP
# ------------sentence: 271 ----------------
# 0 山頭火のあまりのダメ夫ぶりに、兄に説得されて咲野は離婚した。 KEEP
# ------------sentence: 272 ----------------
# 0 しかし妻を愛し続けた山頭火は離婚後も妻のもとへ帰る。 KEEP
# ------------sentence: 273 ----------------
# 0 築地小劇場の旗揚げ公演から演劇生活七十年、俳優座を創立してから五十年、俳優座劇場を開場してから四十年と日本の新劇史と共に歩んできた千田さんだけに、約千人の会葬者の長い列ができた。 KEEP
# ------------sentence: 274 ----------------
# 0 しかし、その発表当日に同市内のアパートで、男女六人の射殺体が発見されている。 KEEP
# ------------sentence: 275 ----------------
# 0 昨年の同市内の犯罪統計によると、殺人事件の被害者は一九九三年の千九百四十六人を約二〇％下回る千五百八十一人となった。 KEEP
# ------------sentence: 276 ----------------
# 0 八日に行われた全国社会人ラグビー大会の決勝で、神戸製鋼は東芝府中を破り、七年連続の優勝。 KEEP
# ------------sentence: 277 ----------------
# 0 新日鉄釜石の七連覇から、ちょうど十年。 KEEP
# ------------sentence: 278 ----------------
# 0 今季は新旧交代に加え、連勝ストップ、主将のけがという試練もあったが、ベテランと若手がかみ合い、うまく乗り越えた神戸製鋼。 KEEP
# ------------sentence: 279 ----------------
# 0 釜石が果たせなかった八連覇も単なる通過点になりそうだ。 KEEP
# ------------sentence: 280 ----------------
# 0 あれから六年、大八木淳史、平尾誠二両選手ら四人を残してメンバーは大幅に入れ替わったが、強さは相変わらずだった。 KEEP
# ------------sentence: 281 ----------------
# 0 平尾選手が涙を流した。 KEEP
# ------------sentence: 282 ----------------
# 0 右足負傷の細川隆弘主将に代わって、チームリーダーも務めた。 KEEP
# ------------sentence: 283 ----------------
# 0 いろいろな思いが沈着冷静な男の頭に去来したようだ。 KEEP
# ------------sentence: 284 ----------------
# 0 この七年間を振り返っても、今季ほど新旧交代が図られたシーズンはなかった。 KEEP
# ------------sentence: 285 ----------------
# 0 元木選手は試合中、脳しんとうを起こした平尾選手からゲームメークを頼まれたという。 KEEP
# ------------sentence: 286 ----------------
# 0 いずれも火の気のないところで、東京消防庁と本所署は連続放火事件とみて調べている。 KEEP
# ------------sentence: 287 ----------------
# 0 八日午前四時二十八分ごろと同五時四十六分ごろ、関東地方を中心に連続して地震があった。 KEEP
# ------------sentence: 288 ----------------
# 0 二回目は震度１が水戸、日光。 KEEP
# ------------sentence: 289 ----------------
# 0 しかし、不自然な点もあるため、なお慎重に捜査を進める方針。 KEEP
# ------------sentence: 290 ----------------
# 0 名護署によると、三人とも首を絞められたり刺されたような外傷や、骨折はなかった。 KEEP
# ------------sentence: 291 ----------------
# 0 三人の遺体は七日午後二時ごろ、同市内の園芸会社の社員が発見した。 KEEP
# ------------sentence: 292 ----------------
# 0 トラックの荷台の肥料散布用タンクの中で、川の字になって死んでいた。 KEEP
# ------------sentence: 293 ----------------
# 0 タンクはグラスファイバー製で上部に直径五十センチのネジ込み式のふたがある。 KEEP
# ------------sentence: 294 ----------------
# 0 同署は七歳の女児に同型のタンクに入ってもらい実験した。 KEEP
# ------------sentence: 295 ----------------
# 0 この結果、手のひらでふたを下から支えるようにして回すと、内部からも開閉できた。 KEEP
# ------------sentence: 296 ----------------
# 0 このため、タンク内に農薬などの薬品が残っていなかったか調べている。 KEEP
# ------------sentence: 297 ----------------
# 0 また、このトラックは十二月十一日から、上間さんの自宅から約五十メートルの駐車場に放置されていた。 KEEP
# ------------sentence: 298 ----------------
# 0 駐車場は人通りの多い道路に面しており、人目は多い。 KEEP
# ------------sentence: 299 ----------------
# 0 この面からも事件性は薄いとの見方がある。 KEEP
# ------------sentence: 300 ----------------
# 0 米軍がルソン島に上陸を開始した。 KEEP
# ------------sentence: 301 ----------------
# 0 東芝府中が KEEP
# 1 前半１９分 KEEP
# 2 トライで KEEP
# 3 試合は KEEP
# 4 先制したが、神戸製鋼は連続攻撃を仕掛け、逆転。 KEEP
# ------------sentence: 302 ----------------
# 0 後半もスタンドオフ平尾選手の活躍などでトライを加えた。 KEEP
# ------------sentence: 303 ----------------
# 0 神戸製鋼は今月十五日、国立競技場で、大学チャンピオンの大東大と日本一をかけて戦う。 KEEP
# ------------sentence: 304 ----------------
# 0 新横綱貴乃花は小結武双山の上手投げに屈し、波乱の幕開けに。 KEEP
# ------------sentence: 305 ----------------
# 0 町選挙管理委員会は KEEP
# 1 用紙の点検を KEEP
# 2 このため KEEP
# 3 深夜になって開票作業を中断 KEEP
# 4 開始。 KEEP
# ------------sentence: 306 ----------------
# 0 同町議選は町長選挙とのダブル選挙。 KEEP
# ------------sentence: 307 ----------------
# 0 定数一六に対し十七人が立候補。 KEEP
# ------------sentence: 308 ----------------
# 0 有権者五千八百四十七人のうち五千五百七十五人が投票した。 KEEP
# ------------sentence: 309 ----------------
# 0 しかし、開票作業を続けているうち各候補の得票総数が投票者数を上回ることが判明。 KEEP
# ------------sentence: 310 ----------------
# 0 チェックしたところ偽造が分かった。 KEEP
# ------------sentence: 311 ----------------
# 0 投票用紙は町議選は薄い緑色、町長選は黄色に色分けされていた。 KEEP
# ------------sentence: 312 ----------------
# 0 偽造用紙は本物より紙が薄めで、朱色で印刷されている線が不鮮明。 KEEP
# ------------sentence: 313 ----------------
# 0 一見しただけではわからないが、点検作業で一枚ずつ手にとってみて、偽造と判明した。 KEEP
# ------------sentence: 314 ----------------
# 0 偽造用紙には、候補者数人の名前が書かれていた。 KEEP
# ------------sentence: 315 ----------------
# 0 町役場研修室の開票所では日付が変わっても選挙結果が発表されず、各陣営の運動員ら四、五十人が押しかけ、説明を求めた。 KEEP
# ------------sentence: 316 ----------------
# 0 小休止のあと、次は春のセンバツが待っています。 KEEP
# ------------sentence: 317 ----------------
# 0 あれから世界は激動。 KEEP
# ------------sentence: 318 ----------------
# 0 この事故で同電車が現場に約三十五分間停車、後続の上下計八本が運休した。 KEEP
# ------------sentence: 319 ----------------
# 0 自殺とみて身元を調べている。 KEEP
# ------------sentence: 320 ----------------
# 0 あれから六年、大八木淳史、平尾両選手ら四人を残し、メンバーは入れ替わったが、強さは変わらなかった。 KEEP
# ------------sentence: 321 ----------------
# 0 表彰式で平尾選手が涙を流した KEEP
# ------------sentence: 322 ----------------
# 0 同財団は一九五〇年の設立後まもなく休眠状態になった。 KEEP
# ------------sentence: 323 ----------------
# 0 日本総合ハウスクリーニング協会に KEEP
# 1 約八千万円で KEEP
# 2 会社社長は KEEP
# 3 九一年 KEEP
# 4 財団の議事録などを偽造し KEEP
# 5 売却。 KEEP
# ------------sentence: 324 ----------------
# 0 同協会に無断で議事録を偽造し、昨年七月、この業者らを理事に就任させた。 KEEP
# ------------sentence: 325 ----------------
# 0 この手形が手形交換所に持ち込まれたことから、金銭トラブルが表面化した。 KEEP
# ------------sentence: 326 ----------------
# 0 法務大臣指定だけで全国に約１８０カ所ある。 KEEP
# ------------sentence: 327 ----------------
# 0 殺害にはいずれも薬物を使ったことをほのめかしており、同本部は家畜の殺処分などに使われていた硝酸ストリキニーネとみている。 KEEP
# ------------sentence: 328 ----------------
# 0 同本部はこのふろ場を重点的に捜索、洗い場の板などを押収し、分析を急いでいる。 KEEP
# ------------sentence: 329 ----------------
# 0 これに基づき KEEP
# 1 同村の山崎容疑者の犬繁殖場から北へ約五キロの沢ぞいで検索を実施 KEEP
# 2 遺骨や遺品の発見に KEEP
# 3 全力を KEEP
# 4 同本部は KEEP
# 5 挙げている。 KEEP
# ------------sentence: 330 ----------------
# 0 一方、殺害に使われた薬物は、硝酸ストリキニーネの可能性が強いことが同本部の調べで分かった。 KEEP
# ------------sentence: 331 ----------------
# 0 獣医師の話では、耳かき一杯分をコップ一杯の水に溶かして一口飲んだだけでも、中枢神経のまひを起こし、数秒で死亡するという。 KEEP
# ------------sentence: 332 ----------------
# 0 ロシア政府は八日夜、チェチェン共和国の首都グロズヌイに進攻したロシア軍部隊が大統領官邸を完全封鎖したと発表した。 KEEP
# ------------sentence: 333 ----------------
# 0 ロシア軍が同官邸に肉薄し激しい砲撃を浴びせたことを KEEP
# 1 ロシアのテレビも KEEP
# 2 同日夜 KEEP
# 3 現地からの報道で KEEP
# 4 伝えており、首都攻撃の最大目標だった大統領官邸を完全封鎖し、首都制圧は目前に迫った模様だ。 KEEP
# ------------sentence: 334 ----------------
# 0 官邸の中央部が炎上しているほか、内部で銃声が響いているとして、ドゥダエフ政権の官邸防衛部隊の内部崩壊を示唆した。 KEEP
# ------------sentence: 335 ----------------
# 0 ロシア政府の発表は、中心部以外では依然として首都のいくつかの地区がチェチェン側の支配下にあると認めている。 KEEP
# ------------sentence: 336 ----------------
# 0 また KEEP
# 1 チェチェン側の捕虜に KEEP
# 2 首都の南西三十キロの村で KEEP
# 3 七日 KEEP
# 4 ロシア軍の精鋭である空てい部隊が KEEP
# 5 なったとも伝えられており、ロシア軍に対するチェチェン側の抵抗は依然各地で続いている模様だ。 KEEP
# ------------sentence: 337 ----------------
# 0 十日の中執委で決定するよう執行部に申し入れる。 KEEP
# ------------sentence: 338 ----------------
# 0 民間情報サミットでは、情報通信関連事業の主導権争いや技術の標準化で利害が対立する各国産業界が率直に意見交換するのが狙い。 KEEP
# ------------sentence: 339 ----------------
# 0 そのうえで、政府だけでなく民間の視点から、地球規模の情報通信基盤の重要性を確認する。 KEEP
# ------------sentence: 340 ----------------
# 0 閣僚会合では、マルチメディア時代をにらみ、光ファイバー網や衛星通信を組み合わせた地球規模の情報通信基盤構想を実現するための世界共通ルールづくりについて協議。 KEEP
# ------------sentence: 341 ----------------
# 0 日本からは大出俊郵政相と橋本竜太郎通産相が出席する。 KEEP
# ------------sentence: 342 ----------------
# 0 毎年十月ごろから同湖にやって来るオオハクチョウ。 KEEP
# ------------sentence: 343 ----------------
# 0 冬のファッションアイテムとしてブーツが今年も人気を集めている。 KEEP
# ------------sentence: 344 ----------------
# 0 頭と足元に注目したら、帽子は少なく、ブーツばかりが目についた。 KEEP
# ------------sentence: 345 ----------------
# 0 恋人同士、女性グループの足取りはやや重そう。 KEEP
# ------------sentence: 346 ----------------
# 0 くるぶしまでのショートブーツも結構多い。 KEEP
# ------------sentence: 347 ----------------
# 0 ミニスカートからジーンズまで、幅広いファッションに対応している。 KEEP
# ------------sentence: 348 ----------------
# 0 銀座や巣鴨では、おしゃれな帽子を見かけなかったので渋谷へ。 KEEP
# ------------sentence: 349 ----------------
# 0 １５年ぐらい前に流行したレシーバーの形をした耳あても今冬、流行の兆しとか。 KEEP
# ------------sentence: 350 ----------------
# 0 服以上に個性を出すことができるので、おしゃれの重要なアイテムであることは間違いない。 KEEP
# ------------sentence: 351 ----------------
# 0 ３回目の契約更改交渉が９日午後行われるが、すんなり関係改善といくかどうか。 KEEP
# ------------sentence: 352 ----------------
# 0 ２回目の交渉はわずか１５分で終わったが、それもそのはず。 KEEP
# ------------sentence: 353 ----------------
# 0 球団社長を前にして一言も口を開かなかったのだという。 KEEP
# ------------sentence: 354 ----------------
# 0 以前 KEEP
# 1 ネタを KEEP
# 2 野茂がフォークやカーブの握りを見せ KEEP
# 3 カウンターの向こうで KEEP
# 4 すし屋のおやじが KEEP
# 5 次々と KEEP
# 6 握ってくれるテレビＣＭがあった。 KEEP
# ------------sentence: 355 ----------------
# 0 ソウル五輪で一緒に銀メダルを獲得した当時の全日本キャプテン、筒井大助さんは振り返る。 KEEP
# ------------sentence: 356 ----------------
# 0 その意味では野茂選手は根っからのピッチャーだと思う。 KEEP
# ------------sentence: 357 ----------------
# 0 新人投手にしてみれば、先輩とはいえチーム内で一軍枠を争うライバル。 KEEP
# ------------sentence: 358 ----------------
# 0 今回の確執は、信頼していたトレーニングコーチの退団がきっかけだった。 KEEP
# ------------sentence: 359 ----------------
# 0 野茂さん KEEP
# 1 いまは KEEP
# 2 ただ KEEP
# 3 米国行きは KEEP
# 4 考えものです。 KEEP
# ------------sentence: 360 ----------------
# 0 強行しても、大リーグそのものが正常な形で開幕するかどうかあやしい。 KEEP
# ------------sentence: 361 ----------------
# 0 労使トラブル余波で日本にも、バリバリの大リーガーが続々来る。 KEEP
# ------------sentence: 362 ----------------
# 0 とりあえず今年は国内で実績を積み上げ、次の機会に備えた方が得策だと思うのだが。 KEEP
# ------------sentence: 363 ----------------
# 0 二百円台のワインの登場で、日本のワイン市場は高級ワインと、普段気楽に飲めるテーブルワインに二極分化してきた。 KEEP
# ------------sentence: 364 ----------------
# 0 実は生産地でも、消費者の動向に合わせた努力が顕著になっている。 KEEP
# ------------sentence: 365 ----------------
# 0 バブル期の造れば売れる時代は過ぎ、明確なワイン造りの戦略が求められているからだ。 KEEP
# ------------sentence: 366 ----------------
# 0 ブルゴーニュ地方の最北部のシャブリは、酸味の利いたキリっとした白ワインの産地。 KEEP
# ------------sentence: 367 ----------------
# 0 生ガキやカキフライ、刺し身などと合うということもあり、日本人にはなじみが深い。 KEEP
# ------------sentence: 368 ----------------
# 0 化学肥料から有機肥料への転換は、すでに九年前に行ったが、殺虫剤についてはここ数年。 KEEP
# ------------sentence: 369 ----------------
# 0 赤グモ、ダニといったブドウの害虫駆除のため、天敵のコガネムシを放つ。 KEEP
# ------------sentence: 370 ----------------
# 0 またブドウの葉を食べるチョウの幼虫対策に、チョウがブドウの葉に産みつけた卵を無力化させるバクテリアを繁殖させる。 KEEP
# ------------sentence: 371 ----------------
# 0 捕チョウ用の粘着板も畑のあちこちに取り付けてある。 KEEP
# ------------sentence: 372 ----------------
# 0 一ヘクタール当たり、ブドウの苗木は普通六千本だが、ここでは七千本。 KEEP
# ------------sentence: 373 ----------------
# 0 苗木にストレスを与え、各樹がつける実を少なくする。 KEEP
# ------------sentence: 374 ----------------
# 0 またせんていで四分の一もの芽を摘み込む。 KEEP
# ------------sentence: 375 ----------------
# 0 生産量は少なくなるが、ブドウの樹液を濃縮し、高品質のブドウを収穫するためだ。 KEEP
# ------------sentence: 376 ----------------
# 0 それがいま曲がり角にあるという。 KEEP
# ------------sentence: 377 ----------------
# 0 化学肥料のカリウムが KEEP
# 1 シャブリの生命ともいえる酸度を KEEP
# 2 かなり KEEP
# 3 シャブリでいうと KEEP
# 4 低下させたからだ。 KEEP
# ------------sentence: 378 ----------------
# 0 有機栽培に踏み切っているところが KEEP
# 1 幾つか KEEP
# 2 米カリフォルニアのワイン生産者の中には KEEP
# 3 すでに KEEP
# 4 ある。 KEEP
# ------------sentence: 379 ----------------
# 0 それからするとさほど珍しくなさそうだが、実はフランスの国情からすると先駆的なのだ。 KEEP
# ------------sentence: 380 ----------------
# 0 仏で有機農法や自然食品への関心が出てきたのは、やっとここ数年で、環境保護運動が低調だった国柄と無縁ではない。 KEEP
# ------------sentence: 381 ----------------
# 0 仏で環境保護運動が台頭するのは八〇年代末。 KEEP
# ------------sentence: 382 ----------------
# 0 八〇年代初頭、西独などで緑の党が台頭し、反核運動と結びついた環境保護運動が盛り上がったのに比べ、十年近い遅れだ。 KEEP
# ------------sentence: 383 ----------------
# 0 ともすれば伝統にあぐらをかいてきた仏のワイン生産者。 KEEP
# ------------sentence: 384 ----------------
# 0 だが、議会指導者が対露支援にかげりを指摘したのは初めて。 KEEP
# ------------sentence: 385 ----------------
# 0 エジプト治安当局によると、同国警官隊が８日、カイロ西郊の町でイスラム原理主義過激派とみられるグループと銃撃戦を展開し、５人を射殺した。 KEEP
# ------------sentence: 386 ----------------
# 0 武村正義蔵相は９日午前、中国とシンガポール、マレーシアの３カ国訪問のため成田空港を出発した。 KEEP
# ------------sentence: 387 ----------------
# 0 １５日までの日程で、各国の蔵相や首脳クラスと会談する。 KEEP
# ------------sentence: 388 ----------------
# 0 豊田会長は具体的に、行政改革推進本部の規制緩和検討委員会が民間からの意見を踏まえて二月九日にまとめる報告書の内容を、五カ年計画に反映させる必要性を強調した。 KEEP
# ------------sentence: 389 ----------------
# 0 ロシア軍とドゥダエフ政権部隊との間で死闘が展開されているチェチェン共和国の首都グロズヌイで、市内に残っている市民約五万人は食料や医薬品が不足し、生死の瀬戸際に追い込まれている。 KEEP
# ------------sentence: 390 ----------------
# 0 だが、食料や飲料水が欠乏し、市民は道路の穴や溝にある水を集めて飲んでいるという。 KEEP
# ------------sentence: 391 ----------------
# 0 また、戦闘に巻き込まれて負傷した市民が少なくないが、診療施設の大半は戦闘で破壊されたうえ、医薬品が欠乏し、手当てを受けられず放置されている状態。 KEEP
# ------------sentence: 392 ----------------
# 0 新日鉄は九日、自動車需要が急激に伸びているタイで、自動車用鋼管の合弁事業を始めることを明らかにした。 KEEP
# ------------sentence: 393 ----------------
# 0 合弁会社は素材の鋼板を日本から輸入、自動車などで使うチューブを製造する。 KEEP
# ------------sentence: 394 ----------------
# 0 投資額は約二十億円程度で、一九九六年初めからの生産を予定しており、生産規模は年間二万トン。 KEEP
# ------------sentence: 395 ----------------
# 0 軍幹部を KEEP
# 1 ロシアの事実上の最高政策決定機関、安全保障会議のメンバーでもあるシャフライ副首相が KEEP
# 2 七日夜 KEEP
# 3 チェチェン紛争をめぐって KEEP
# 4 公然と KEEP
# 5 非難した。 KEEP
# ------------sentence: 396 ----------------
# 0 疑問を KEEP
# 1 同副首相は KEEP
# 2 先に KEEP
# 3 今回のロシア軍の作戦遂行能力に KEEP
# 4 呈したばかりで、政権内部の亀裂が表面化した形だ。 KEEP
# ------------sentence: 397 ----------------
# 0 この指摘は先にチェチェン紛争の仲介役を買って出たハズブラトフ旧ロシア最高会議議長も行っていたが、政権幹部がこれに言及したのは初めて。 KEEP
# ------------sentence: 398 ----------------
# 0 同副首相によると、この際に引き渡された兵器には装甲車や銃砲、戦闘機などが含まれているという。 KEEP
# ------------sentence: 399 ----------------
# 0 歴史と伝統の重みをすごく感じます。 KEEP
# ------------sentence: 400 ----------------
# 0 歴史を見ると大変な時代があったが、先輩が乗り越えてきた。 KEEP
# ------------sentence: 401 ----------------
# 0 これからもよりよい芝居を提供していきたい。 KEEP
# ------------sentence: 402 ----------------
# 0 客席もかなりゆったりしたスペースになるとか。 KEEP
# ------------sentence: 403 ----------------
# 0 二階最前列正面の客席を三〇センチ迫り出し、舞台により親近感を持てるように改造します。 KEEP
# ------------sentence: 404 ----------------
# 0 音響システムも現在最高水準のデジタル化を進め、音質や全体のハーモニーにも十分配慮。 KEEP
# ------------sentence: 405 ----------------
# 0 主演級の人のために KEEP
# 1 四室 KEEP
# 2 現在 KEEP
# 3 大部屋のほか KEEP
# 4 あります。 KEEP
# ------------sentence: 406 ----------------
# 0 五年前にバス、トイレを付け大改造しましたが、今回は天井を高くしたりクロゼットを設け、内装もリニューアル。 KEEP
# ------------sentence: 407 ----------------
# 0 より居住性の高いものにしました。 KEEP
# ------------sentence: 408 ----------------
# 0 存分に力を発揮出来るように。 KEEP
# ------------sentence: 409 ----------------
# 0 今回は外装も内装も和風の感じを前面に押し出した改装になります。 KEEP
# ------------sentence: 410 ----------------
# 0 娘さんが中学受験に失敗した体験をもとに生み出したもので、受験戦争をコミカルに描く。 KEEP
# ------------sentence: 411 ----------------
# 0 上演は十二日から十五日まで。 KEEP
# ------------sentence: 412 ----------------
# 0 それを KEEP
# 1 軽飛行機の代名詞として KEEP
# 2 得意げに KEEP
# 3 彼は KEEP
# 4 しゃべった。 KEEP
# ------------sentence: 413 ----------------
# 0 こういう例は、特別に知識を持たない人にとってはよくあることだ。 KEEP
# ------------sentence: 414 ----------------
# 0 カタカナが圧倒的に多いのは現代日本語の状況を反映していることもあるだろうが、伝統的な一般呼称がなかったものや新しいものが多いということでもあると思う。 KEEP
# ------------sentence: 415 ----------------
# 0 私たちの記憶に KEEP
# 1 技術革新などで全く新しい商品が現れると KEEP
# 2 その普及力が強いほど KEEP
# 3 その商品名が KEEP
# 4 植え付けられてしまうのかもしれない。 KEEP
# ------------sentence: 416 ----------------
# 0 セスナという言葉を教えてくれた友や私が無自覚のうちに企業の宣伝塔になっていたと考えるのは愉快なことではない。 KEEP
# ------------sentence: 417 ----------------
# 0 手を尽くして調べた結果、百十三点が現存。 KEEP
# ------------sentence: 418 ----------------
# 0 この転身のプロセスは、現在の作家の表現を考察する上でも、いろんな示唆を含んだものだ。 KEEP
# ------------sentence: 419 ----------------
# 0 たしかに作品の需給上の問題を度外視しても、単独でしか存在しない作品を複数化させたいという心理が、作家の側に働くのはあり得ないことではない。 KEEP
# ------------sentence: 420 ----------------
# 0 とりわけ完成状態が想像の中でしか存在できないのが、厄介でもありかつスリリングなところだろう。 KEEP
# ------------sentence: 421 ----------------
# 0 艾澤の手がける銅版画の場合は、これに腐食の偶発性も加わるから作家のコントロールの幅は、もっと狭まることになる。 KEEP
# ------------sentence: 422 ----------------
# 0 つまり艾澤が、この間接性をあえて選んだのは、ある時から自己中心的な造形主義に対する懐疑の念が強まったせいではなかろうか。 KEEP
# ------------sentence: 423 ----------------
# 0 具体的な対象物でもなければ、観念のこしらえものでもない特異なイメージが、その間接的な手法によって次々と生み出されていったからだ。 KEEP
# ------------sentence: 424 ----------------
# 0 今回発表された近作群を見ても、艾澤の充実ぶりが生々しく伝わってくる。 KEEP
# ------------sentence: 425 ----------------
# 0 版画に対する人々の既成観念を引っくり返すような強さを、それらはみなぎらせているといっていい。 KEEP
# ------------sentence: 426 ----------------
# 0 画面をねっとりと覆っていく黒い流れ。 KEEP
# ------------sentence: 427 ----------------
# 0 見えるはずもない生命の核心にひそむものが、姿かたちを取って立ち現れたような心地といおうか。 KEEP
# ------------sentence: 428 ----------------
# 0 サウンドは７０年代のファンクを下敷きに、打ち込みを一切使わず、民族楽器を使ったグルーブ感重視のもの。 KEEP
# ------------sentence: 429 ----------------
# 0 前回のライブハウスは身動きのとれない状態だったので今回はホール中心。 KEEP
# ------------sentence: 430 ----------------
# 0 ２月末から３月中旬まで全国１１カ所で。 KEEP
# ------------sentence: 431 ----------------
# 0 楽しさ抜群のフィンランドの音楽隊。 KEEP
# ------------sentence: 432 ----------------
# 0 高橋克典は演技者より歌手の自分をアピールする。 KEEP
# ------------sentence: 433 ----------------
# 0 ふり絞るハスキーな歌唱は魅力。 KEEP
# ------------sentence: 434 ----------------
# 0 オンは橘いずみがどう武道館を処理するか。 KEEP
# ------------sentence: 435 ----------------
# 0 写真で首に巻いているマフラーは、インタビューの直前に歌手の荻野目洋子さんにプレゼントされたものである。 KEEP
# ------------sentence: 436 ----------------
# 0 ナラダは８年前に彼女のアルバムをプロデュースしており、荻野目ちゃんが、彼の来日を知って表敬訪問したのだ。 KEEP
# ------------sentence: 437 ----------------
# 0 自らのそのパワーは神と心の中から冥想めいそうを介してやってくると、正面切ってのたまう。 KEEP
# ------------sentence: 438 ----------------
# 0 例えば、こう言う。 KEEP
# ------------sentence: 439 ----------------
# 0 昨年十一月八日に横浜公演を皮切りに大阪、京都、名古屋などで上演、千田は横浜公演に駆け付けるなど、意欲を見せていた。 KEEP
# ------------sentence: 440 ----------------
# 0 亡くなる前に演出プランが出来ていたため、飯沢プラン通り演出が行われた。 KEEP
# ------------sentence: 441 ----------------
# 0 黒柳徹子が六話すべての女主人公にふんする。 KEEP
# ------------sentence: 442 ----------------
# 0 ほかに、小松政夫、石野陽子、金子信雄らが出演。 KEEP
# ------------sentence: 443 ----------------
# 0 毎年、今年の椿姫はだれが歌うのかなと考えるだけでも楽しい。 KEEP
# ------------sentence: 444 ----------------
# 0 デヴィヌーはそれをほぼすべてそろえていた。 KEEP
# ------------sentence: 445 ----------------
# 0 特にピアニシモの美しさは見事。 KEEP
# ------------sentence: 446 ----------------
# 0 チャンバラの迫力が並の映画と違う。 KEEP
# ------------sentence: 447 ----------------
# 0 研究者らはこれまでに、ウコンが細胞に成長の合図を送る遺伝子を抑制する働きがあることを突き止めている。 KEEP
# ------------sentence: 448 ----------------
# 0 同病院の医師らはこの働きを利用し、遺伝子を抑えることで、がんの成長を抑制できるとみている。 KEEP
# ------------sentence: 449 ----------------
# 0 インドや米国、ハンガリーの医師らもウコンを使ってがんの治療法の研究をしているが、臨床試験を行うのは初めてという。 KEEP
# ------------sentence: 450 ----------------
# 0 病院側は成功すればウコンで薬をつくり、売り出したいとしている。 KEEP
# ------------sentence: 451 ----------------
# 0 雨が当たらないベランダの棚、エアコンの室外機などにハトが巣を作る。 KEEP
# ------------sentence: 452 ----------------
# 0 特に、共働き、独身など、人の出入りが少ないマンションに被害が集中しているという。 KEEP
# ------------sentence: 453 ----------------
# 0 すると、ハトが止まろうとしても、足でテグスを握ることができず、寄りつかなくなったという。 KEEP
# ------------sentence: 454 ----------------
# 0 ポリャコフ飛行士はなおミールにとどまり、四百二十九日間まで記録を伸ばす。 KEEP
# ------------sentence: 455 ----------------
# 0 過去に二百四十一日間の宇宙滞在歴がある同飛行士は、昨年一月八日にカザフスタンのバイコヌール宇宙基地から飛び立った。 KEEP
# ------------sentence: 456 ----------------
# 0 医師である同飛行士は、長期間の無重力生活が人体に与える影響を調査、来るべき火星への有人飛行のためのデータを集めている。 KEEP
# ------------sentence: 457 ----------------
# 0 火星への飛行には片道約一年かかるとされる。 KEEP
# ------------sentence: 458 ----------------
# 0 これまでの宇宙連続滞在記録は、ソ連時代の一九八七年から八八年にかけてチトフ、マナロフ両飛行士が達成した三百六十六日間。 KEEP
# ------------sentence: 459 ----------------
# 0 守備面ではコンビが合わない場面もあったが、それを割り引いても余りある大活躍。 KEEP
# ------------sentence: 460 ----------------
# 0 チームは大林の加入で上位進出に期待をかけている。 KEEP
# ------------sentence: 461 ----------------
# 0 意見聴取会は、航空事故原因究明のため事故関係者らから意見を集める手続き。 KEEP
# ------------sentence: 462 ----------------
# 0 事故調はエアバス社、中華航空関係者らに公述を委嘱するほか、学識経験者らから公述の申し出を受け付けている。 KEEP
# ------------sentence: 463 ----------------
# 0 しかし、これまで学識経験のない遺族が公述人に選ばれた例はない。 KEEP
# ------------sentence: 464 ----------------
# 0 一つは、公明県本部が十二月上旬、党員と知人約千三百人にアンケートしたもの。 KEEP
# ------------sentence: 465 ----------------
# 0 もう一つは、同県の地方政党、神奈川ネットワークが十一月、会員と一般市民三千七百人を対象に行ったもの。 KEEP
# ------------sentence: 466 ----------------
# 0 どちらも身近な人の意見を集めたものだから、これで県民全体の意向が分かったとはいえない。 KEEP
# ------------sentence: 467 ----------------
# 0 まして全国の傾向を推しはかるのもむりがある。 KEEP
# ------------sentence: 468 ----------------
# 0 今年は統一地方選の年。 KEEP
# ------------sentence: 469 ----------------
# 0 年明けとともに各地で、知事候補の選考が大詰めを迎えている。 KEEP
# ------------sentence: 470 ----------------
# 0 知事といえば、まず官僚が挙がる。 KEEP
# ------------sentence: 471 ----------------
# 0 でも調査を見ると、このご都合主義に有権者は一番シラケている。 KEEP
# ------------sentence: 472 ----------------
# 0 開票作業を KEEP
# 1 このため KEEP
# 2 町選挙管理委員会は KEEP
# 3 深夜になって KEEP
# 4 中断、用紙の点検を行い、偽造用紙を除外して再集計し、九日午前一時四十分にようやく確定した。 KEEP
# ------------sentence: 473 ----------------
# 0 岡山県警は公選法違反の疑いで捜査を始めた。 KEEP
# ------------sentence: 474 ----------------
# 0 同町議選は町長選挙とのダブル選挙で実施。 KEEP
# ------------sentence: 475 ----------------
# 0 しかし、開票作業を続けているうち、各候補の得票総数が投票者数を上回ることが判明。 KEEP
# ------------sentence: 476 ----------------
# 0 チェックしたところ、偽造が分かった。 KEEP
# ------------sentence: 477 ----------------
# 0 偽造用紙は本物より紙が薄めで、朱色で印刷された文字や公印の部分が不鮮明。 KEEP
# ------------sentence: 478 ----------------
# 0 一見しただけでは分からないが、点検作業で一枚ずつ手に取ってみて、偽造と分かった。 KEEP
# ------------sentence: 479 ----------------
# 0 他人の宅地四五〇平方メートルの登記簿謄本などを KEEP
# 1 調べによると KEEP
# 2 榎本容疑者は KEEP
# 3 椎名仁、増田政美両容疑者らと共謀し KEEP
# 4 偽造。 KEEP
# ------------sentence: 480 ----------------
# 0 同署によると、三人は昨年十二月三十日、上高地から入山。 KEEP
# ------------sentence: 481 ----------------
# 0 警視庁小松川署は二人の行方を追っている。 KEEP
# ------------sentence: 482 ----------------
# 0 前夜は KEEP
# 1 家族と KEEP
# 2 夕食を KEEP
# 3 生徒は KEEP
# 4 食べた。 KEEP
# ------------sentence: 483 ----------------
# 0 未明に家を出て、九階建ての同マンションから飛び降りたらしい。 KEEP
# ------------sentence: 484 ----------------
# 0 この日は三学期の始業式で制服姿だった。 KEEP
# ------------sentence: 485 ----------------
# 0 東京、神奈川、千葉、埼玉など首都圏の多くの公立学校で九日、三学期の始業式が行われた。 KEEP
# ------------sentence: 486 ----------------
# 0 自殺とみて身元確認を急いでいる。 KEEP
# ------------sentence: 487 ----------------
# 0 この事故で、計十六本の電車に最高三十分の遅れが出、乗客一万七千人の足が乱れた。 KEEP
# ------------sentence: 488 ----------------
# 0 判決は来月二日に言い渡される。 KEEP
# ------------sentence: 489 ----------------
# 0 同校長会あてに文章の削除を求める意見書を出していたことが分かった。 KEEP
# ------------sentence: 490 ----------------
# 0 日本の高校教育のあり方や将来像を、海外の教育事情などを織り交ぜながら検討。 KEEP
# ------------sentence: 491 ----------------
# 0 合計二十人もの死者が KEEP
# 1 米国の多くの地域が悪天候に見舞われ KEEP
# 2 大規模な竜巻や暴風雨で KEEP
# 3 六日から八日までの三日間で KEEP
# 4 出た。 KEEP
# ------------sentence: 492 ----------------
# 0 また KEEP
# 1 七日、瞬間風速が六七メートルにも達する暴風雨に襲われ、二人が死亡、数十人が負傷したほか KEEP
# 2 約二万世帯が KEEP
# 3 停電と KEEP
# 4 カリフォルニア州北部は KEEP
# 5 なった。 KEEP
# ------------sentence: 493 ----------------
# 0 米東海岸沿いの地域も悪天候で道路が凍結し、合計十七人の犠牲者が出たという。 KEEP
# ------------sentence: 494 ----------------
# 0 大本営の公式発表だけでも緊迫度は分かる。 KEEP
# ------------sentence: 495 ----------------
# 0 近畿のほとんどの小、中、高校で九日、三学期の始業式があった。 KEEP
# ------------sentence: 496 ----------------
# 0 冬休みに書いた書き初めや図工の作品などを KEEP
# 1 この後 KEEP
# 2 子供たちは KEEP
# 3 教室に入り KEEP
# 4 提出した。 KEEP
# ------------sentence: 497 ----------------
# 0 西日本ではほとんどないグループ。 KEEP
# ------------sentence: 498 ----------------
# 0 大浦暁江容疑者と長嶺容疑者は直前になって出馬を取りやめた。 KEEP
# ------------sentence: 499 ----------------
# 0 長嶺容疑者と大浦夫婦は、立候補を取りやめた報酬と知りながら現金を受け取った疑い。 KEEP
# ------------sentence: 500 ----------------
# 0 輸入が解禁された米国産リンゴの輸入第一船が名古屋港に入港、九日午前、植物検疫と通関手続きが行われた。 KEEP
# ------------sentence: 501 ----------------
# 0 解禁は、昨年五月のニュージーランド産に次ぐ第二弾。 KEEP
# ------------sentence: 502 ----------------
# 0 神戸港では、神戸植物防疫所職員が、大手商社などがシアトルから輸入したワシントン州産ゴールデンデリシャス、レッドデリシャス計約四二〇トンを検査した。 KEEP
# ------------sentence: 503 ----------------
# 0 神戸や大阪の卸売市場を通じて KEEP
# 1 京阪神の小売店の店頭に KEEP
# 2 リンゴは KEEP
# 3 午後から KEEP
# 4 並ぶ。 KEEP
# ------------sentence: 504 ----------------
# 0 同小では六日が始業式だったが、三人の遺体が七日午後見つかってから初めての登校日。 KEEP
# ------------sentence: 505 ----------------
# 0 最後に全員で黙とう。 KEEP
# ------------sentence: 506 ----------------
# 0 二年一組にある一明君の机には、赤いカーネーションやバラの花束と一明君が使っていたけん盤ハーモニカが供えられた。 KEEP
# ------------sentence: 507 ----------------
# 0 司法解剖を終えた三人の遺体は八日夜、遺族に引き渡された。 KEEP
# ------------sentence: 508 ----------------
# 0 商都の繁華街に残る戦争の痕跡が思わぬ形でクローズアップされた格好だ。 KEEP
# ------------sentence: 509 ----------------
# 0 現在はレコード店など三店が建っている。 KEEP
# ------------sentence: 510 ----------------
# 0 地元の不動産業者が昨年二月、国などを相手どり、大阪地裁に所有権確認の訴えを起こし、係争中。 KEEP
# ------------sentence: 511 ----------------
# 0 大阪大空襲などで KEEP
# 1 訴状などによると KEEP
# 2 付近一帯は KEEP
# 3 戦争末期 KEEP
# 4 大半が焼失。 KEEP
# ------------sentence: 512 ----------------
# 0 終戦直後、業者がこの近辺で所有していた土地は闇市に占拠された。 KEEP
# ------------sentence: 513 ----------------
# 0 業者の主張は、自分の所有物でなくても一定期間占有すれば所有権が認められる民法一六二条の取得時効を根拠にしたもの。 KEEP
# ------------sentence: 514 ----------------
# 0 一方、同振興組合は一昨年七月から総工費約十八億八千万円をかけ老朽化した旧アーケードの全面改装工事を始めた。 KEEP
# ------------sentence: 515 ----------------
# 0 しかし、問題の土地について不動産業者が所有権を主張し、裁判に持ち込んだためらちがあかず、関西国際空港の開港に合わせた昨年十月に完成の予定も大幅に遅れた。 KEEP
# ------------sentence: 516 ----------------
# 0 このためこの土地の建物部分だけを残して今年三月をめどに工事を完成させることにしている。 KEEP
# ------------sentence: 517 ----------------
# 0 首に細いヒモ状のもので絞められた跡があり、京都府警捜査一課は桂署に捜査本部を設置、殺人、死体遺棄事件として捜査を始めた。 KEEP
# ------------sentence: 518 ----------------
# 0 死後約半日で、堤防の外側斜面にうつ伏せの状態で死んでいた。 KEEP
# ------------sentence: 519 ----------------
# 0 女性の身元の確認を急ぐとともに KEEP
# 1 付近に争った跡がないことなどから KEEP
# 2 他の場所で殺害され、捨てられたと KEEP
# 3 捜査一課などは KEEP
# 4 見ている。 KEEP
# ------------sentence: 520 ----------------
# 0 夜間は人通りはほとんどないという。 KEEP
# ------------sentence: 521 ----------------
# 0 川西署の調べでは、現場は県道が立体交差しており、陸橋になった柳谷大橋から飛び降りたらしい。 KEEP
# ------------sentence: 522 ----------------
# 0 同署員が自宅を調べたところ、多方さんの妻が居間の布団の中で、中学三年生の長女が自室のベッドで死んでいた。 KEEP
# ------------sentence: 523 ----------------
# 0 居間にあった日記には、家庭内のもめ事について書かれており、同署は多方さんが将来を悲観して妻と長女を道づれに心中を図ったとみている。 KEEP
# ------------sentence: 524 ----------------
# 0 約二十年間にわたりヘリコプターの整備士をしていた。 KEEP
# ------------sentence: 525 ----------------
# 0 長女はこの日が始業式。 KEEP
# ------------sentence: 526 ----------------
# 0 翌日は骨折していた足をけったりしたという。 KEEP
# ------------sentence: 527 ----------------
# 0 同十四日、中一の男子生徒に因縁をつけ、顔や腹などを殴ったりけった疑い。 KEEP
# ------------sentence: 528 ----------------
# 0 被害にあった二人は一週間のけが。 KEEP
# ------------sentence: 529 ----------------
# 0 さらに、中一男子生徒への暴行を止めに入った先生にもけるなどし一週間のけがをさせた疑いもある。 KEEP
# ------------sentence: 530 ----------------
# 0 二人は同校の八人の不良グループの中心メンバー。 KEEP

# %%
count
# Out:
# 490
